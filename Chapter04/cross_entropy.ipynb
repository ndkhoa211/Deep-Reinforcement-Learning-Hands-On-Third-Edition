# %% [markdown]
# # The Cross-Entroy Method

# %% [markdown]
# 1. Despite the fact that it is much less famous than other tools in the RL practitioner's toolbox, such as `deep Q-network (DQN)` or `advantage actor-critic (A2C)`, the `cross-entropy (CE) method` has its own strength:
#     1. easy, simple to follow. Pytorch implementation with just $<100$ lines of code
#     2. has good convergence, works well in simple environments that
#         - don't require us to learn complex. multistep policies, and
#         - have short episodes with frequent rewards
#
# 2. We'll cover:
#     1. the practical side of the `cross-entropy (CE) method`
#     2. how the `cross-entropy (CE) method` works in $2$ environments in Gym:
#         - CartPole
#         - the grid world of FrozenLake
#     3. the theoretical background of the `cross-entropy (CE) method`

# %% [markdown]
# ## 1. The taxonomy of RL methods

# %% [markdown]
# 1. all the methods in RL can be classified into various groups:
#     1. `model-free` or `model-based`
#     2. `value-based` or `policy-based`
#     3. `on-policy` or `off-policy`
#
# 2. there are other ways to taxonomize RL methods, but for now we are interested in the above $3$. Let's define them (as the specifics of our problem can influence our choice of a particular method):
#     1. `model-free` or `model-based`:
#         - `model-free`: the method doesn't build a model of the environment or reward; it just directly connects observations to actions (or values that are related to actions)
#             - in other words, the agent takes current observations and does some computations on them, and the result is the action that it should take
#             - usually easier to train because it's hard to build good models of complex environments with rich observations
#         - `model-based`: try to predict what the next observation and/or reward will be
#             - based on this prediction, the agent tries to choose the best possible action to take, very often making such predictions multiple times to look more and more steps into the future
#             - pure `model-based` methods are usually used in deterministic environments (e.g. board games with strict rules)
#         - all methods described in this book are from `model-free` category (as they have been the most active area of research for the past few year)
#             - only recently have researchers started to mix the benefits from both worlds (refer to [Chapter20](../Chapter20/) and take a look of the `AlphaGo Zero` and `MuZero` methods, which use a model-based approach to board games and Atari)
#     2. `value-based` or `policy-based`:
#         - `policy-based` (PART 3): directly approximate the policy of the agent (what actions the agent should carry out at every step)
#             - the policy is usually represented by a probability distribution over the available actions
#         - `value-based` (PART 2): instead of the probability of actions, the agent calculates the value of every possible action and chooses the action with best value
#     3. `on-policy` or `off-policy`: will be discussed in depth in PARTS 2 & 3
#         - `off-policy`: is able to learn from historical data (obtained by a previous version of the agent, recorded by human demonstration, or just seen by the same agent several episodes ago)
#         - `on-policy`: require fresh data for training, generated from the policy we're currently updating
#             - they cannot be trained on old historical data because the result of the training will be wrong -> less data-efficient (we need much more communication with the environment)
#             - but in some case, this is not a problem (the environment is very lightweight and fast, so we can quickly interact with it)
#
# 3. the `CE method` falls into the `model-free`, `policy-based`, and `on-policy` categories of methods, which means:
#     1. it doesn't build a model of the environment; it just says to the agent what to do at every step
#     2. it approximates the policy of the agent
#     3. it requires fresh data obtained from the environment

# %% [markdown]
# ## 2. The cross-entropy method in practice

# %% [markdown]
# 1. Recall that the agent tries to accumulate as much total reward as possible by communicating with the environment:
#     - in practice, we follow a common ML approach and replace all the complications of the agent with some kind of nonlinear function, which maps the agent's input (observations from the environment) to some output
#     - output may depends on a particular method or a family of methods (such as `value-based` or `policy-based` methods)
#     - as our `CE method` is `policy-based`, our nonlinear function (`neural network (NN)`) produces the `policy`, which basically says for every observation which action the agent should take
#     - in research, `policy` is denoted as $\pi(a|s)$, where:
#         - `a`: actions
#         - `s`: the current states
#
# 2. A high-level approach to `policy-based` RL: ![A high-level approach to policy-based RL](../images/figure_4-1.png)
#     - in practice, the policy is usually represented as a probability distribution over actions (very similar to a classification problem, with the number of classes being equal to the number of actions we can carry out)
#     - this abstraction makes our agent very simple: it needs to pass an observation from the environment to the NN, get a probability distibution over actions, and perform random sampling using the probability distribution to get an action to carry out
#         - this random sampling adds randomness to our agent (a good thing because at the begining of the training, when our weights are random, the agent behaves randomly)
#         - as soon as the agent gets an action to issue, it fires the action to the environment and obtains the next observation and reward for the last action. Then the loop continues
#
# 3. during the agent's lifetime, its experience is presented as episodes:
#     - every episode is a sequence of observations that the agent has got from the environment, actions it has issued, and rewards for these actions
#         - imagine that our agent has played several episodes
#         - for every episode, we can calculate the total reward that the agent has claimed (can be discounted or not discounted)
#         - for simplicity, assumue a discount factor of $\gamma = 1$, i.e. an undiscounted sum of local rewards for every episode
#     - this total reward shows how good this episode was for the agent
#         - ![Example episodes with their observations, actions, and rewards](../images/figure_4-2.png) contains $4$ episodes (note that different episodes have different values for $o_i$, $a_i$, and $r_i$)
#         - every cell represents the agent's step in the episode
#         - due to randomness in the environment and the way that the agent selects actions to take, some episodes will be better thatn others
#     - the core of the `CE method` is to throw away bad episode and train on better ones. The steps of `CE method`:
#         1. play $N$ episodes using our current model and environment
#         2. calculate the total reward for every episode and decide on a reward boundary
#             - usually we use a percentile of all reward, e.g. $50{th}$ or $70^{th}$
#         3. throw away all episodes with a reward below the boundary
#         4. train on the remaining `"elite"` episodes (with rewards higher than the boundary) using observations as the input and issued actions as the desired output
#         5. repear from step `1.` until we become satisfied with the result
#     - with `CE method`, our NN learns how to repeat actions, which leads to a larger reward, constantly moving the boundary higher and higher

# %% [markdown]
# ## 3. The cross-entropy method on CartPole

# %% [markdown]
# Refer to [cartpole script](01_cartpole.py):

# %%
#!/usr/bin/env python3
import numpy as np
import gymnasium as gym
from dataclasses import dataclass
import typing as tt
from torch.utils.tensorboard.writer import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim


HIDDEN_SIZE = 128
BATCH_SIZE = 16
PERCENTILE = 70


class Net(nn.Module):
    def __init__(self, obs_size: int, hidden_size: int, n_actions: int):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x: torch.Tensor):
        return self.net(x)


@dataclass
class EpisodeStep:
    observation: np.ndarray
    action: int

@dataclass
class Episode:
    reward: float
    steps: tt.List[EpisodeStep]


def iterate_batches(env: gym.Env, net: Net, batch_size: int) -> tt.Generator[tt.List[Episode], None, None]:
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs, _ = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.tensor(obs, dtype=torch.float32)
        act_probs_v = sm(net(obs_v.unsqueeze(0)))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, is_trunc, _ = env.step(action)
        episode_reward += float(reward)
        step = EpisodeStep(observation=obs, action=action)
        episode_steps.append(step)
        if is_done or is_trunc:
            e = Episode(reward=episode_reward, steps=episode_steps)
            batch.append(e)
            episode_reward = 0.0
            episode_steps = []
            next_obs, _ = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch: tt.List[Episode], percentile: float) -> \
        tt.Tuple[torch.FloatTensor, torch.LongTensor, float, float]:
    rewards = list(map(lambda s: s.reward, batch))
    reward_bound = float(np.percentile(rewards, percentile))
    reward_mean = float(np.mean(rewards))

    train_obs: tt.List[np.ndarray] = []
    train_act: tt.List[int] = []
    for episode in batch:
        if episode.reward < reward_bound:
            continue
        train_obs.extend(map(lambda step: step.observation, episode.steps))
        train_act.extend(map(lambda step: step.action, episode.steps))

    train_obs_v = torch.FloatTensor(np.vstack(train_obs))
    train_act_v = torch.LongTensor(train_act)
    return train_obs_v, train_act_v, reward_bound, reward_mean


if __name__ == "__main__":
    # env = gym.make("CartPole-v1")
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    env = gym.wrappers.RecordVideo(env, video_folder="video")
    assert env.observation_space.shape is not None
    obs_size = env.observation_space.shape[0]
    assert isinstance(env.action_space, gym.spaces.Discrete)
    n_actions = int(env.action_space.n)

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    print(net)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.01)
    writer = SummaryWriter(comment="-cartpole")

    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
        obs_v, acts_v, reward_b, reward_m = filter_batch(batch, PERCENTILE)
        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, reward_mean=%.1f, rw_bound=%.1f" % (
            iter_no, loss_v.item(), reward_m, reward_b))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_bound", reward_b, iter_no)
        writer.add_scalar("reward_mean", reward_m, iter_no)
        if reward_m > 475:
            print("Solved!")
            break
    writer.close()
# Out:
# Net(
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# 0: loss=0.688, reward_mean=27.7, rw_bound=32.0
# 1: loss=0.679, reward_mean=26.1, rw_bound=31.0
# 2: loss=0.669, reward_mean=33.9, rw_bound=37.5
# 3: loss=0.647, reward_mean=46.6, rw_bound=52.0
# 4: loss=0.633, reward_mean=39.8, rw_bound=47.0
# 5: loss=0.625, reward_mean=39.5, rw_bound=52.0
# 6: loss=0.621, reward_mean=42.8, rw_bound=57.0
# 7: loss=0.623, reward_mean=53.6, rw_bound=57.5
# 8: loss=0.590, reward_mean=56.2, rw_bound=62.5
# 9: loss=0.592, reward_mean=54.3, rw_bound=64.0
# 10: loss=0.591, reward_mean=63.2, rw_bound=65.5
# 11: loss=0.593, reward_mean=77.4, rw_bound=94.0
# 12: loss=0.590, reward_mean=68.1, rw_bound=71.0
# 13: loss=0.582, reward_mean=62.9, rw_bound=73.0
# 14: loss=0.561, reward_mean=63.6, rw_bound=66.5
# 15: loss=0.560, reward_mean=57.6, rw_bound=63.5
# 16: loss=0.551, reward_mean=57.9, rw_bound=57.0
# 17: loss=0.566, reward_mean=57.0, rw_bound=68.0
# 18: loss=0.553, reward_mean=72.3, rw_bound=69.5
# 19: loss=0.554, reward_mean=70.8, rw_bound=74.5
# 20: loss=0.568, reward_mean=81.9, rw_bound=96.5
# 21: loss=0.536, reward_mean=98.7, rw_bound=118.5
# 22: loss=0.559, reward_mean=95.8, rw_bound=113.5
# 23: loss=0.561, reward_mean=91.2, rw_bound=96.5
# 24: loss=0.531, reward_mean=82.1, rw_bound=85.0
# 25: loss=0.511, reward_mean=77.6, rw_bound=82.0
# 26: loss=0.532, reward_mean=79.2, rw_bound=84.5
# 27: loss=0.550, reward_mean=92.3, rw_bound=105.5
# 28: loss=0.528, reward_mean=105.0, rw_bound=122.0
# 29: loss=0.535, reward_mean=141.5, rw_bound=172.0
# 30: loss=0.524, reward_mean=177.8, rw_bound=227.0
# 31: loss=0.536, reward_mean=163.2, rw_bound=177.5
# 32: loss=0.531, reward_mean=132.3, rw_bound=170.5
# 33: loss=0.534, reward_mean=158.4, rw_bound=162.0
# 34: loss=0.535, reward_mean=169.4, rw_bound=171.5
# 35: loss=0.531, reward_mean=159.7, rw_bound=175.5
# 36: loss=0.520, reward_mean=175.7, rw_bound=186.5
# 37: loss=0.522, reward_mean=266.9, rw_bound=297.0
# 38: loss=0.520, reward_mean=263.4, rw_bound=306.0
# 39: loss=0.525, reward_mean=336.3, rw_bound=424.5
# 40: loss=0.520, reward_mean=398.7, rw_bound=500.0
# 41: loss=0.512, reward_mean=387.8, rw_bound=500.0
# 42: loss=0.516, reward_mean=415.8, rw_bound=500.0
# 43: loss=0.518, reward_mean=371.9, rw_bound=500.0
# 44: loss=0.519, reward_mean=458.1, rw_bound=500.0
# 45: loss=0.514, reward_mean=448.4, rw_bound=500.0
# 46: loss=0.512, reward_mean=472.1, rw_bound=500.0
# 47: loss=0.518, reward_mean=421.9, rw_bound=500.0
# 48: loss=0.512, reward_mean=478.9, rw_bound=500.0
# Solved!

# %% [markdown]
# 1. **Line 13-15**: define constants/hyperparams:
#     - **Line 13**: our model's core is a one-hidden-layer NN, with ReLU and $128$ hidden neurons (randomly set, not tuned)
#     - **Line 14**: the count of episodes we play on every iteration ($16$)
#     - **Line 15**: the percentile of each episode's total reward that we use for elite episode filtering; we'll keep the top $30%$ of episodes sorted by reward
#
# 2. **Line 18-28**: our NN takes a single observation from the environment and outputs a number for every action we can perform:
#     - output is the probability distribution over actions
#         - so a straightforward way to proceed would be to include softmax after the last layer
#     - however, in the code, we don't apply softmax to increase the numerical stability of the training process. Rather than:
#         1. calculating softmax (which uses exponention) and then
#         2. calculating cross-entropy loss (which uses a logarithm of probas)
#     - we'll use the Pytorch class `nn.CrossEntropyLoss` later, which combines both into a single, more numerically stable expression
#         - `nn.CrossEntropyLoss` requires raw, unnormalized values from NN (called `logits`)
#         - downside: we need to remember to apply softmax every time we need to get probas from NN's output
#
# 3. **Line 31-39**: define $2$ helper `dataclass`es. The purposes:
#     1. `EpisodeStep`: used to represent one single step that our agent made in the episode, and it stores the observation from the environment and what action the agent performed
#         - we'll use episode steps from elite episodes as training data
#     2. `Episode`: a single episode stored as a total undiscounted reward and a collection of `EpisodeStep`
#
# 4. **Line 42-66**: `iterate_batch()` function generates batches with episodes:
#     - **Line 42-47**: accept the environment (`Env` class instance), our NN, and the count of episodes it should generate on evey iteration
#         - `batch`: used to accumulate our batch (which is a list of `Episode` instances)
#         - `episode_reward`: a reward counter for the current episode
#         - `episode_steps`: (the `EpisodeStep` object) list of steps
#         - `obs`: first observation after `reset()`
#         - `sm`: softmax layer, used to convert NN's output to a proba distribution of actions
#     - **Line 48-51**: start the environment loop. At every iteration, we convert our current observation to a Pytorch tensor and pass it to NN to obtain action probas. Note:
#         1. **Line 49-50**: all `nn.Module` instances expect a batch of data items, so we
#             1. convert our observation into tensor and
#             2. add an extra dimension at the $0^{th}$ dim using `unsqueezed(0)` method, then
#             3. feed the raw action scores (aka NN's output) through softmax
#         2. **Line 51**: both NN and softmax layer return tensors that track gradients, so we need to unpack this by accessing `tensor.data` field and converting to Numpy array, then we get the first batch element to obtain a one-dim vector of action probas
#     - **Line 52-53**: use proba distribution of actions to obtain the actual action for the current step:
#         1. **Line 52**: sample distribution using Numpy function `random.choice()`
#         2. **Line 53**: pass this `action` to the environment to get our:
#             1. next observation `next_obs`
#             2. `reward`
#             3. the indication of the episode ending `is_done`
#             4. the truncation flag `is_trunc`
#             5. last value returned by `step()` function is extra info from the environment and is discarded
#     - **Line 54-56**: `reward` is added to the current episode's total reward `episode_reward`, and our list of `episode_steps` is also extended with an `(observation, action)` pair
#         - note: we save the obsevation that was used to choose the action (`obs`), but not the observation returned by the environment as a result of the action (`next_obs`)
#     - **Line 57-66**: handles the situation when the current episode is over:
#         1. in CartPole case, the episode ends when
#             1. the stick has fallen down
#             2. time limit of the environment has been reached
#         2. **Line 58-59**: we append the finalized episode to the batch, saving the total reward (as the episode has ben completed and we've accumulated all the rewards) and steps we have taken
#         3. **Line 60-61**: then reset total reward accumulator `episode_reward` and clean the list of steps `episode_steps`
#         4. **Line 62**: after that, we reset our environment and start over
#         5. **Line 63-64**: if our batch has reached the desired count of episodes `batch_size`, we return it to the caller for processing using `yield`
#             - our function is a generator, so every tume the `yield` operator is executed, the control is transferred to the outer iteration loop and then continues after the `yield` line
#         6. **Line 65**: after processing, we'll clean up the `batch`
#         7. **Line 66**: (IMPORTANT) assign an observation obtained from the environment `next_obs` to our current observation variable `obs`
#         8. after that, everything repeats infinitely
#             1. pass the observation to NN
#             2. sample the action to perform
#             3. ask the environment to process the action
#             4. remember the result of this processing
#         9. `ONE IMPORTANT FACT TO UNDERSTAND THIS FUNCTION'S LOGIT`: the training of NN and the generation of our episode are performed `at the same time`
#             - they are not completely parallel, but every time our loop accumulates enough episodes (`16`), it passes control to this function caller, which is supposed to train the NN using gradient descent `GD`
#             - so, when `yield` is returned, NN will have different, slightly better (we hope) behavior
#             - as we should remember from the begining, `CE method` is from the `on-policy` class, so using fresh training data is important for the method to work properly
#         10. since traing and data gathering in the same thread, proper synchronization isn't necessary
#             - however, we should be aware of the frequent jumps between training the NN and using it
#
# 5. **Line 69-85**: define `filter_batch()` function htat lies at the core of the `CE method`:
#     - **Line 69-73**: from the given `batch` of episodes and `percentile` value, it
#         1. **Line 71-72**: calculate a boundary reward `reward_bound` (used to filter elite episodes to train on) using Numpy's `percentile()` function
#         2. **Line 73**: calculate `reward_mean` (used for monitoring)
#     - **Line 75-81**: we'll filter off our episodes
#         - for every episode in the batch, we'll check that the episode has a higher total reward than our boundary
#         - if it has, we'll populate lists of observations and actions we'll train on
#     - **Line 83-85**: convert our observations and actions from elite episodes into tensors, and return a tuple of $4$: observations, actions, the boundary of reward, and the mean reward
#         - the last $2$ not used in traing; we'll write them in TensorBoard to check the performance of our agent
#
# 6. **Line 88-118**: let's glue everything together, and mostly consists of the training loop:
#     - **Line 88-101**: create all the required objects:
#         1. the environment
#         2. NN
#         3. the `objective()` function
#         4. the optimizer
#         5. the summary writer for TensorBoard
#     - **Line 103-109**: in the training loop, we iterate our batches (a list of `Episode` objects):
#         1. **Line 104**: `filter_batch()` filter the elite episodes, the result is
#             1. tensors of observations
#             2. taken actions
#             3. the reward boundary used for filtering
#             4. the mean reward
#         2. **Line 105**: zero gradients of our NN
#         3. **Line 106**: pass observations to the NN, obtaining its action scores
#         4. **Line 107**: the `objective()` function uses these scores to calclulate the `CE` (between the NN output and the actions that the agent took)
#             - the idea if this is to reinfoce our NN to carry out those elite actions that have led to good rewards
#         5. **Line 108-109**: calculate gradients on the loss and ask the optimizer to adjust our NN
#     - **Line 110-114**: monitor the progress
#         1. **Line 110-111**: on the console, we show
#             1. the iteration number
#             2. the loss
#             3. the mean reward of the batch
#             4. the reward boundary
#         2. **Line 112-114**: write the same values to TensorBoard to get a nice chart of the agent's learning performance
#     - **Line 115-118**: compare the mean rewards of our batch episodes
#         - when mean reward $> 475$, we stop our training. Why $475$?
#             - in Gym, `CartPole-v1` environment is considered to be solved when mean reward for the last $100$ episodes is $>475$
#             - however, our method converges so quickly that $100$ episodes are usually what we need
#             - the properly trained agent can balance the stick for an infinitely long period of time (obtaining any amount of score), but the length of an episode in `CartPole-v1` is [limited to 500 steps](https://github.com/Farama-Foundation/Gymnasium/blob/main/gymnasium/envs/__init__.py)
#
# 7. **Line 90-91**: uncomment these lines to monitor the training process. We can tweak the environment by
#     1. **Line 90**: setting the rendering mode in the CartPole environment, and
#     2. **Line 91**: adding a `RecordVideo` wrapper to create a `/video` folder with a bunch of MP4 movies inside
#
# 8. REFLECTION:
#     - our NN has learned how to play the environment purely from observations and rewards, without any interpretation of observed values
#     - our implementation doesn't depend on environment-related details
#
# 9. start `TensorBoard` and look at the result by:
#     1. open terminal
#     2. type `tensorboard --logdir runs` inside `/Chapter04` folder
#     3. open `http://localhost:6006/`
#     4. run on a remote server and make it accessible from other machines: `tensorboard --logdir runs -bind_all`
#
# 10. Let's take a look of some visualizations:
#     1. Mean reward: ![Cartpole mean reward](../images/ch04_cartpole_reward_mean.png)
#     2. Loss: ![Cartpole loss](../images/ch04_cartpole_loss.png)
#     3. Reward boundary during the training: ![Cartpole reward boundary during the training](../images/ch04_cartpole_reward_bound.png)
#     4. Cartpole video episode $729$:

# %%
from IPython.display import Video

VIDEO_PATH = "video/rl-video-episode-729.mp4"

# With autoplay and loop
Video(VIDEO_PATH, 
      embed=True, # for self-contained notebook
      html_attributes="controls autoplay loop")
# Out:
# <video controls autoplay loop  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## 4. The cross-entropy method on FrozenLake

# %% [markdown]
# 1. FrozenLake's world is of grid world category
#     - agent lives in a grid of size $4\times 4$ and can move in $4$ directions
#     - agent always starts at top-left and its goal is to reach bottom-right cell of the grid
#     - there are holes in the fixed cells of the grid and if the agent gets into those holes, the episode ends and the reward is zero
#     - if the agent reaches the bottom-right cell, the episode ends and the reward is $1.0$
#
# 2. the world is slipery, so the agent's actions do not always turn out as expected:
#     - the agent will move in
#         1. intended direction with probability specified by `success_rate` $(r)$
#         2. either perpendicular direction with equal probability $\left(\frac{1-r}{2}\right)$ in both direction
#
# 3. Let's take a look of the environment: ![The FrozenLake environment rendered in human mode](../images/figure_4-6.png)

# %%
e =gym.make("FrozenLake-v1", render_mode="ansi")

print(f"Observation space: {e.observation_space}")
print(f"Action space: {e.action_space}")
# Out:
# Observation space: Discrete(16)
# Action space: Discrete(4)

# %%
e.reset()
# Out:
# (0, {'prob': 1})

# %%
print(e.render())
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# Refer to [frozen lake naive script](02_frozenlake_naive.py):

# %%
#!/usr/bin/env python3
import numpy as np
import gymnasium as gym
from dataclasses import dataclass
import typing as tt
from torch.utils.tensorboard.writer import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim


HIDDEN_SIZE = 128
BATCH_SIZE = 16
PERCENTILE = 70


class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env: gym.Env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        shape = (env.observation_space.n, )
        self.observation_space = gym.spaces.Box(0.0, 1.0, shape, dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res


class Net(nn.Module):
    def __init__(self, obs_size: int, hidden_size: int,
                 n_actions: int):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


@dataclass
class EpisodeStep:
    observation: np.ndarray
    action: int

@dataclass
class Episode:
    reward: float
    steps: tt.List[EpisodeStep]


def iterate_batches(env: gym.Env, net: Net, batch_size: int) -> \
        tt.Generator[tt.List[Episode], None, None]:
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs, _ = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.tensor(obs, dtype=torch.float32)
        act_probs_v = sm(net(obs_v.unsqueeze(0)))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, is_trunc, _ = env.step(action)
        episode_reward += float(reward)
        step = EpisodeStep(observation=obs, action=action)
        episode_steps.append(step)
        if is_done or is_trunc:
            e = Episode(reward=episode_reward, steps=episode_steps)
            batch.append(e)
            episode_reward = 0.0
            episode_steps = []
            next_obs, _ = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch: tt.List[Episode], percentile: float) -> \
        tt.Tuple[torch.FloatTensor, torch.LongTensor, float, float]:
    rewards = list(map(lambda s: s.reward, batch))
    reward_bound = float(np.percentile(rewards, percentile))
    reward_mean = float(np.mean(rewards))

    train_obs: tt.List[np.ndarray] = []
    train_act: tt.List[int] = []
    for episode in batch:
        if episode.reward < reward_bound:
            continue
        train_obs.extend(map(lambda step: step.observation,
                             episode.steps))
        train_act.extend(map(lambda step: step.action,
                             episode.steps))

    train_obs_v = torch.FloatTensor(np.vstack(train_obs))
    train_act_v = torch.LongTensor(train_act)
    return train_obs_v, train_act_v, reward_bound, reward_mean


if __name__ == "__main__":
    env = DiscreteOneHotWrapper(gym.make("FrozenLake-v1"))
    obs_size = env.observation_space.shape[0]
    n_actions = int(env.action_space.n)

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.01)
    writer = SummaryWriter(comment="-frozenlake-naive")

    for iter_no, batch in enumerate(
            iterate_batches(env, net, BATCH_SIZE)):
        obs_v, acts_v, reward_b, reward_m = \
            filter_batch(batch, PERCENTILE)
        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, reward_mean=%.1f, reward_bound=%.1f" % (
            iter_no, loss_v.item(), reward_m, reward_b))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_bound", reward_b, iter_no)
        writer.add_scalar("reward_mean", reward_m, iter_no)
        if reward_m > 0.8:
            print("Solved!")
            break
    writer.close()
# Out:
# 0: loss=1.377, reward_mean=0.1, reward_bound=0.0
# 1: loss=1.353, reward_mean=0.0, reward_bound=0.0
# 2: loss=1.329, reward_mean=0.0, reward_bound=0.0
# 3: loss=1.348, reward_mean=0.0, reward_bound=0.0
# 4: loss=1.331, reward_mean=0.0, reward_bound=0.0
# 5: loss=1.284, reward_mean=0.1, reward_bound=0.0
# 6: loss=1.230, reward_mean=0.0, reward_bound=0.0
# 7: loss=1.244, reward_mean=0.0, reward_bound=0.0
# 8: loss=1.295, reward_mean=0.0, reward_bound=0.0
# 9: loss=1.254, reward_mean=0.1, reward_bound=0.0
# 10: loss=1.218, reward_mean=0.1, reward_bound=0.0
# 11: loss=1.257, reward_mean=0.1, reward_bound=0.0
# 12: loss=1.219, reward_mean=0.0, reward_bound=0.0
# 13: loss=1.153, reward_mean=0.0, reward_bound=0.0
# 14: loss=1.162, reward_mean=0.0, reward_bound=0.0
# 15: loss=1.142, reward_mean=0.0, reward_bound=0.0
# 16: loss=1.170, reward_mean=0.0, reward_bound=0.0
# 17: loss=1.198, reward_mean=0.0, reward_bound=0.0
# 18: loss=1.205, reward_mean=0.1, reward_bound=0.0
# 19: loss=1.145, reward_mean=0.0, reward_bound=0.0
# 20: loss=1.210, reward_mean=0.0, reward_bound=0.0
# 21: loss=1.128, reward_mean=0.0, reward_bound=0.0
# 22: loss=1.150, reward_mean=0.0, reward_bound=0.0
# 23: loss=1.095, reward_mean=0.0, reward_bound=0.0
# 24: loss=1.115, reward_mean=0.0, reward_bound=0.0
# 25: loss=1.111, reward_mean=0.0, reward_bound=0.0
# 26: loss=1.186, reward_mean=0.0, reward_bound=0.0
# 27: loss=1.097, reward_mean=0.0, reward_bound=0.0
# 28: loss=1.043, reward_mean=0.0, reward_bound=0.0
# 29: loss=1.096, reward_mean=0.0, reward_bound=0.0
# 30: loss=0.926, reward_mean=0.0, reward_bound=0.0
# 31: loss=1.060, reward_mean=0.0, reward_bound=0.0
# 32: loss=1.091, reward_mean=0.0, reward_bound=0.0
# 33: loss=0.962, reward_mean=0.0, reward_bound=0.0
# 34: loss=0.980, reward_mean=0.0, reward_bound=0.0
# 35: loss=1.012, reward_mean=0.0, reward_bound=0.0
# 36: loss=0.972, reward_mean=0.0, reward_bound=0.0
# 37: loss=0.888, reward_mean=0.0, reward_bound=0.0
# 38: loss=0.926, reward_mean=0.0, reward_bound=0.0
# 39: loss=1.030, reward_mean=0.0, reward_bound=0.0
# 40: loss=0.776, reward_mean=0.0, reward_bound=0.0
# 41: loss=0.947, reward_mean=0.0, reward_bound=0.0
# 42: loss=0.821, reward_mean=0.0, reward_bound=0.0
# 43: loss=0.894, reward_mean=0.0, reward_bound=0.0
# 44: loss=0.954, reward_mean=0.0, reward_bound=0.0
# 45: loss=0.888, reward_mean=0.0, reward_bound=0.0
# 46: loss=0.850, reward_mean=0.0, reward_bound=0.0
# 47: loss=0.867, reward_mean=0.0, reward_bound=0.0
# 48: loss=0.899, reward_mean=0.0, reward_bound=0.0
# 49: loss=0.855, reward_mean=0.0, reward_bound=0.0
# 50: loss=0.870, reward_mean=0.1, reward_bound=0.0
# 51: loss=0.779, reward_mean=0.0, reward_bound=0.0
# 52: loss=0.865, reward_mean=0.0, reward_bound=0.0
# 53: loss=0.822, reward_mean=0.0, reward_bound=0.0
# 54: loss=0.794, reward_mean=0.0, reward_bound=0.0
# 55: loss=0.799, reward_mean=0.1, reward_bound=0.0
# 56: loss=0.832, reward_mean=0.0, reward_bound=0.0
# 57: loss=0.844, reward_mean=0.0, reward_bound=0.0
# 58: loss=0.698, reward_mean=0.0, reward_bound=0.0
# 59: loss=0.773, reward_mean=0.0, reward_bound=0.0
# 60: loss=0.938, reward_mean=0.0, reward_bound=0.0
# 61: loss=0.769, reward_mean=0.0, reward_bound=0.0
# 62: loss=0.914, reward_mean=0.0, reward_bound=0.0
# 63: loss=0.939, reward_mean=0.0, reward_bound=0.0
# 64: loss=0.831, reward_mean=0.0, reward_bound=0.0
# 65: loss=0.870, reward_mean=0.1, reward_bound=0.0
# 66: loss=0.953, reward_mean=0.0, reward_bound=0.0
# 67: loss=0.968, reward_mean=0.0, reward_bound=0.0
# 68: loss=0.881, reward_mean=0.0, reward_bound=0.0
# 69: loss=0.990, reward_mean=0.0, reward_bound=0.0
# 70: loss=0.952, reward_mean=0.0, reward_bound=0.0
# 71: loss=1.020, reward_mean=0.0, reward_bound=0.0
# 72: loss=0.965, reward_mean=0.0, reward_bound=0.0
# 73: loss=1.121, reward_mean=0.0, reward_bound=0.0
# 74: loss=1.065, reward_mean=0.0, reward_bound=0.0
# 75: loss=1.088, reward_mean=0.0, reward_bound=0.0
# 76: loss=0.992, reward_mean=0.0, reward_bound=0.0
# 77: loss=1.191, reward_mean=0.0, reward_bound=0.0
# 78: loss=1.176, reward_mean=0.0, reward_bound=0.0
# 79: loss=1.179, reward_mean=0.1, reward_bound=0.0
# 80: loss=1.167, reward_mean=0.0, reward_bound=0.0
# 81: loss=1.134, reward_mean=0.1, reward_bound=0.0
# 82: loss=1.133, reward_mean=0.0, reward_bound=0.0
# 83: loss=0.990, reward_mean=0.1, reward_bound=0.0
# 84: loss=1.019, reward_mean=0.0, reward_bound=0.0
# 85: loss=1.095, reward_mean=0.0, reward_bound=0.0
# 86: loss=1.016, reward_mean=0.0, reward_bound=0.0
# 87: loss=1.089, reward_mean=0.0, reward_bound=0.0
# 88: loss=0.980, reward_mean=0.1, reward_bound=0.0
# 89: loss=0.840, reward_mean=0.0, reward_bound=0.0
# 90: loss=0.863, reward_mean=0.1, reward_bound=0.0
# 91: loss=0.885, reward_mean=0.0, reward_bound=0.0
# 92: loss=0.839, reward_mean=0.0, reward_bound=0.0
# 93: loss=0.973, reward_mean=0.1, reward_bound=0.0
# 94: loss=0.909, reward_mean=0.0, reward_bound=0.0
# 95: loss=0.823, reward_mean=0.1, reward_bound=0.0
# 96: loss=0.873, reward_mean=0.1, reward_bound=0.0
# 97: loss=0.788, reward_mean=0.0, reward_bound=0.0
# 98: loss=0.815, reward_mean=0.0, reward_bound=0.0
# 99: loss=0.840, reward_mean=0.0, reward_bound=0.0
# 100: loss=0.670, reward_mean=0.1, reward_bound=0.0
# 101: loss=0.767, reward_mean=0.1, reward_bound=0.0
# 102: loss=0.774, reward_mean=0.0, reward_bound=0.0
# 103: loss=0.841, reward_mean=0.1, reward_bound=0.0
# 104: loss=0.695, reward_mean=0.0, reward_bound=0.0
# 105: loss=0.697, reward_mean=0.0, reward_bound=0.0
# 106: loss=0.674, reward_mean=0.1, reward_bound=0.0
# 107: loss=0.746, reward_mean=0.0, reward_bound=0.0
# 108: loss=0.561, reward_mean=0.0, reward_bound=0.0
# 109: loss=0.639, reward_mean=0.0, reward_bound=0.0
# 110: loss=0.407, reward_mean=0.0, reward_bound=0.0
# 111: loss=0.522, reward_mean=0.0, reward_bound=0.0
# 112: loss=0.495, reward_mean=0.0, reward_bound=0.0
# 113: loss=0.379, reward_mean=0.0, reward_bound=0.0
# 114: loss=0.601, reward_mean=0.1, reward_bound=0.0
# 115: loss=0.310, reward_mean=0.1, reward_bound=0.0
# 116: loss=0.291, reward_mean=0.1, reward_bound=0.0
# 117: loss=0.270, reward_mean=0.1, reward_bound=0.0
# 118: loss=0.211, reward_mean=0.0, reward_bound=0.0
# 119: loss=0.322, reward_mean=0.1, reward_bound=0.0
# 120: loss=0.406, reward_mean=0.0, reward_bound=0.0
# 121: loss=0.226, reward_mean=0.0, reward_bound=0.0
# 122: loss=0.185, reward_mean=0.0, reward_bound=0.0
# 123: loss=0.168, reward_mean=0.1, reward_bound=0.0
# 124: loss=0.042, reward_mean=0.0, reward_bound=0.0
# 125: loss=0.178, reward_mean=0.1, reward_bound=0.0
# 126: loss=0.091, reward_mean=0.1, reward_bound=0.0
# 127: loss=0.271, reward_mean=0.0, reward_bound=0.0
# 128: loss=0.025, reward_mean=0.1, reward_bound=0.0
# 129: loss=0.117, reward_mean=0.0, reward_bound=0.0
# 130: loss=0.104, reward_mean=0.0, reward_bound=0.0
# 131: loss=0.023, reward_mean=0.1, reward_bound=0.0
# 132: loss=0.081, reward_mean=0.1, reward_bound=0.0
# 133: loss=0.236, reward_mean=0.0, reward_bound=0.0
# 134: loss=0.069, reward_mean=0.0, reward_bound=0.0
# 135: loss=0.123, reward_mean=0.0, reward_bound=0.0
# 136: loss=0.054, reward_mean=0.0, reward_bound=0.0
# 137: loss=0.126, reward_mean=0.0, reward_bound=0.0
# 138: loss=0.071, reward_mean=0.0, reward_bound=0.0
# 139: loss=0.049, reward_mean=0.0, reward_bound=0.0
# 140: loss=0.069, reward_mean=0.0, reward_bound=0.0
# 141: loss=0.139, reward_mean=0.1, reward_bound=0.0
# 142: loss=0.013, reward_mean=0.0, reward_bound=0.0
# 143: loss=0.010, reward_mean=0.1, reward_bound=0.0
# 144: loss=0.051, reward_mean=0.0, reward_bound=0.0
# 145: loss=0.070, reward_mean=0.0, reward_bound=0.0
# 146: loss=0.010, reward_mean=0.0, reward_bound=0.0
# 147: loss=0.010, reward_mean=0.1, reward_bound=0.0
# 148: loss=0.106, reward_mean=0.0, reward_bound=0.0
# 149: loss=0.071, reward_mean=0.0, reward_bound=0.0
# 150: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 151: loss=0.008, reward_mean=0.0, reward_bound=0.0
# 152: loss=0.087, reward_mean=0.1, reward_bound=0.0
# 153: loss=0.008, reward_mean=0.1, reward_bound=0.0
# 154: loss=0.156, reward_mean=0.0, reward_bound=0.0
# 155: loss=0.009, reward_mean=0.0, reward_bound=0.0
# 156: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 157: loss=0.078, reward_mean=0.1, reward_bound=0.0
# 158: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 159: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 160: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 161: loss=0.008, reward_mean=0.1, reward_bound=0.0
# 162: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 163: loss=0.143, reward_mean=0.0, reward_bound=0.0
# 164: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 165: loss=0.054, reward_mean=0.0, reward_bound=0.0
# 166: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 167: loss=0.005, reward_mean=0.1, reward_bound=0.0
# 168: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 169: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 170: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 171: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 172: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 173: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 174: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 175: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 176: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 177: loss=0.087, reward_mean=0.0, reward_bound=0.0
# 178: loss=0.168, reward_mean=0.0, reward_bound=0.0
# 179: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 180: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 181: loss=0.088, reward_mean=0.1, reward_bound=0.0
# 182: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 183: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 184: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 185: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 186: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 187: loss=0.065, reward_mean=0.1, reward_bound=0.0
# 188: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 189: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 190: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 191: loss=0.077, reward_mean=0.1, reward_bound=0.0
# 192: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 193: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 194: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 195: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 196: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 197: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 198: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 199: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 200: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 201: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 202: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 203: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 204: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 205: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 206: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 207: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 208: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 209: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 210: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 211: loss=0.083, reward_mean=0.1, reward_bound=0.0
# 212: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 213: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 214: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 215: loss=0.061, reward_mean=0.1, reward_bound=0.0
# 216: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 217: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 218: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 219: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 220: loss=0.083, reward_mean=0.1, reward_bound=0.0
# 221: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 222: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 223: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 224: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 225: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 226: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 227: loss=0.066, reward_mean=0.0, reward_bound=0.0
# 228: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 229: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 230: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 231: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 232: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 233: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 234: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 235: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 236: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 237: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 238: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 239: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 240: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 241: loss=0.075, reward_mean=0.0, reward_bound=0.0
# 242: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 243: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 244: loss=0.065, reward_mean=0.1, reward_bound=0.0
# 245: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 246: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 247: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 248: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 249: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 250: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 251: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 252: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 253: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 254: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 255: loss=0.046, reward_mean=0.1, reward_bound=0.0
# 256: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 257: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 258: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 259: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 260: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 261: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 262: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 263: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 264: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 265: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 266: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 267: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 268: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 269: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 270: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 271: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 272: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 273: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 274: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 275: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 276: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 277: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 278: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 279: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 280: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 281: loss=0.071, reward_mean=0.1, reward_bound=0.0
# 282: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 283: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 284: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 285: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 286: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 287: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 288: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 289: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 290: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 291: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 292: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 293: loss=0.056, reward_mean=0.0, reward_bound=0.0
# 294: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 295: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 296: loss=0.074, reward_mean=0.1, reward_bound=0.0
# 297: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 298: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 299: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 300: loss=0.070, reward_mean=0.1, reward_bound=0.0
# 301: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 302: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 303: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 304: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 305: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 306: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 307: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 308: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 309: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 310: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 311: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 312: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 313: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 314: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 315: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 316: loss=0.101, reward_mean=0.0, reward_bound=0.0
# 317: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 318: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 319: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 320: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 321: loss=0.069, reward_mean=0.0, reward_bound=0.0
# 322: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 323: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 324: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 325: loss=0.048, reward_mean=0.0, reward_bound=0.0
# 326: loss=0.084, reward_mean=0.0, reward_bound=0.0
# 327: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 328: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 329: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 330: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 331: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 332: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 333: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 334: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 335: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 336: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 337: loss=0.046, reward_mean=0.1, reward_bound=0.0
# 338: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 339: loss=0.122, reward_mean=0.0, reward_bound=0.0
# 340: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 341: loss=0.050, reward_mean=0.0, reward_bound=0.0
# 342: loss=0.044, reward_mean=0.1, reward_bound=0.0
# 343: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 344: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 345: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 346: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 347: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 348: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 349: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 350: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 351: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 352: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 353: loss=0.059, reward_mean=0.0, reward_bound=0.0
# 354: loss=0.096, reward_mean=0.1, reward_bound=0.0
# 355: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 356: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 357: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 358: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 359: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 360: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 361: loss=0.104, reward_mean=0.1, reward_bound=0.0
# 362: loss=0.068, reward_mean=0.0, reward_bound=0.0
# 363: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 364: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 365: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 366: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 367: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 368: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 369: loss=0.094, reward_mean=0.0, reward_bound=0.0
# 370: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 371: loss=0.108, reward_mean=0.0, reward_bound=0.0
# 372: loss=0.077, reward_mean=0.1, reward_bound=0.0
# 373: loss=0.005, reward_mean=0.1, reward_bound=0.0
# 374: loss=0.038, reward_mean=0.1, reward_bound=0.0
# 375: loss=0.036, reward_mean=0.0, reward_bound=0.0
# 376: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 377: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 378: loss=0.078, reward_mean=0.0, reward_bound=0.0
# 379: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 380: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 381: loss=0.042, reward_mean=0.1, reward_bound=0.0
# 382: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 383: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 384: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 385: loss=0.034, reward_mean=0.1, reward_bound=0.0
# 386: loss=0.005, reward_mean=0.1, reward_bound=0.0
# 387: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 388: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 389: loss=0.007, reward_mean=0.1, reward_bound=0.0
# 390: loss=0.009, reward_mean=0.1, reward_bound=0.0
# 391: loss=0.039, reward_mean=0.1, reward_bound=0.0
# 392: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 393: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 394: loss=0.005, reward_mean=0.2, reward_bound=0.0
# 395: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 396: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 397: loss=0.050, reward_mean=0.0, reward_bound=0.0
# 398: loss=0.070, reward_mean=0.1, reward_bound=0.0
# 399: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 400: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 401: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 402: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 403: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 404: loss=0.033, reward_mean=0.0, reward_bound=0.0
# 405: loss=0.036, reward_mean=0.1, reward_bound=0.0
# 406: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 407: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 408: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 409: loss=0.005, reward_mean=0.1, reward_bound=0.0
# 410: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 411: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 412: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 413: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 414: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 415: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 416: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 417: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 418: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 419: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 420: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 421: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 422: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 423: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 424: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 425: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 426: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 427: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 428: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 429: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 430: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 431: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 432: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 433: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 434: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 435: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 436: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 437: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 438: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 439: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 440: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 441: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 442: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 443: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 444: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 445: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 446: loss=0.090, reward_mean=0.0, reward_bound=0.0
# 447: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 448: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 449: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 450: loss=0.127, reward_mean=0.0, reward_bound=0.0
# 451: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 452: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 453: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 454: loss=0.000, reward_mean=0.2, reward_bound=0.0
# 455: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 456: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 457: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 458: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 459: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 460: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 461: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 462: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 463: loss=0.048, reward_mean=0.0, reward_bound=0.0
# 464: loss=0.096, reward_mean=0.0, reward_bound=0.0
# 465: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 466: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 467: loss=0.001, reward_mean=0.2, reward_bound=0.0
# 468: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 469: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 470: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 471: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 472: loss=0.084, reward_mean=0.0, reward_bound=0.0
# 473: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 474: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 475: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 476: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 477: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 478: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 479: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 480: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 481: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 482: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 483: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 484: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 485: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 486: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 487: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 488: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 489: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 490: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 491: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 492: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 493: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 494: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 495: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 496: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 497: loss=0.086, reward_mean=0.1, reward_bound=0.0
# 498: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 499: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 500: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 501: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 502: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 503: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 504: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 505: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 506: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 507: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 508: loss=0.076, reward_mean=0.1, reward_bound=0.0
# 509: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 510: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 511: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 512: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 513: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 514: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 515: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 516: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 517: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 518: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 519: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 520: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 521: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 522: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 523: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 524: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 525: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 526: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 527: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 528: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 529: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 530: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 531: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 532: loss=0.063, reward_mean=0.0, reward_bound=0.0
# 533: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 534: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 535: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 536: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 537: loss=0.062, reward_mean=0.0, reward_bound=0.0
# 538: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 539: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 540: loss=0.103, reward_mean=0.0, reward_bound=0.0
# 541: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 542: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 543: loss=0.097, reward_mean=0.0, reward_bound=0.0
# 544: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 545: loss=0.001, reward_mean=0.2, reward_bound=0.0
# 546: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 547: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 548: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 549: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 550: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 551: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 552: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 553: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 554: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 555: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 556: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 557: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 558: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 559: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 560: loss=0.002, reward_mean=0.2, reward_bound=0.0
# 561: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 562: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 563: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 564: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 565: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 566: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 567: loss=0.074, reward_mean=0.1, reward_bound=0.0
# 568: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 569: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 570: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 571: loss=0.001, reward_mean=0.2, reward_bound=0.0
# 572: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 573: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 574: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 575: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 576: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 577: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 578: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 579: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 580: loss=0.096, reward_mean=0.1, reward_bound=0.0
# 581: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 582: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 583: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 584: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 585: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 586: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 587: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 588: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 589: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 590: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 591: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 592: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 593: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 594: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 595: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 596: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 597: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 598: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 599: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 600: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 601: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 602: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 603: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 604: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 605: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 606: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 607: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 608: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 609: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 610: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 611: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 612: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 613: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 614: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 615: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 616: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 617: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 618: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 619: loss=0.085, reward_mean=0.2, reward_bound=0.0
# 620: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 621: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 622: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 623: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 624: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 625: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 626: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 627: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 628: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 629: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 630: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 631: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 632: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 633: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 634: loss=0.096, reward_mean=0.0, reward_bound=0.0
# 635: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 636: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 637: loss=0.078, reward_mean=0.1, reward_bound=0.0
# 638: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 639: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 640: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 641: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 642: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 643: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 644: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 645: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 646: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 647: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 648: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 649: loss=0.001, reward_mean=0.2, reward_bound=0.0
# 650: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 651: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 652: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 653: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 654: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 655: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 656: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 657: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 658: loss=0.079, reward_mean=0.0, reward_bound=0.0
# 659: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 660: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 661: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 662: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 663: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 664: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 665: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 666: loss=0.148, reward_mean=0.1, reward_bound=0.0
# 667: loss=0.115, reward_mean=0.1, reward_bound=0.0
# 668: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 669: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 670: loss=0.103, reward_mean=0.1, reward_bound=0.0
# 671: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 672: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 673: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 674: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 675: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 676: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 677: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 678: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 679: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 680: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 681: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 682: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 683: loss=0.074, reward_mean=0.0, reward_bound=0.0
# 684: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 685: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 686: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 687: loss=0.127, reward_mean=0.0, reward_bound=0.0
# 688: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 689: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 690: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 691: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 692: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 693: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 694: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 695: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 696: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 697: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 698: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 699: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 700: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 701: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 702: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 703: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 704: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 705: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 706: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 707: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 708: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 709: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 710: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 711: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 712: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 713: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 714: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 715: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 716: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 717: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 718: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 719: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 720: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 721: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 722: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 723: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 724: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 725: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 726: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 727: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 728: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 729: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 730: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 731: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 732: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 733: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 734: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 735: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 736: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 737: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 738: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 739: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 740: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 741: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 742: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 743: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 744: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 745: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 746: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 747: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 748: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 749: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 750: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 751: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 752: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 753: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 754: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 755: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 756: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 757: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 758: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 759: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 760: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 761: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 762: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 763: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 764: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 765: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 766: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 767: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 768: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 769: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 770: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 771: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 772: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 773: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 774: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 775: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 776: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 777: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 778: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 779: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 780: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 781: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 782: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 783: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 784: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 785: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 786: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 787: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 788: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 789: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 790: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 791: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 792: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 793: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 794: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 795: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 796: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 797: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 798: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 799: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 800: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 801: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 802: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 803: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 804: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 805: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 806: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 807: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 808: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 809: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 810: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 811: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 812: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 813: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 814: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 815: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 816: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 817: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 818: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 819: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 820: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 821: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 822: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 823: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 824: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 825: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 826: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 827: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 828: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 829: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 830: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 831: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 832: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 833: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 834: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 835: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 836: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 837: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 838: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 839: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 840: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 841: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 842: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 843: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 844: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 845: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 846: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 847: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 848: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 849: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 850: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 851: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 852: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 853: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 854: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 855: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 856: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 857: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 858: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 859: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 860: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 861: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 862: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 863: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 864: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 865: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 866: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 867: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 868: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 869: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 870: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 871: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 872: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 873: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 874: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 875: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 876: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 877: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 878: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 879: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 880: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 881: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 882: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 883: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 884: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 885: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 886: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 887: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 888: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 889: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 890: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 891: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 892: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 893: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 894: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 895: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 896: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 897: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 898: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 899: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 900: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 901: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 902: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 903: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 904: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 905: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 906: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 907: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 908: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 909: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 910: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 911: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 912: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 913: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 914: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 915: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 916: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 917: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 918: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 919: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 920: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 921: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 922: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 923: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 924: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 925: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 926: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 927: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 928: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 929: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 930: loss=0.109, reward_mean=0.0, reward_bound=0.0
# 931: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 932: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 933: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 934: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 935: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 936: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 937: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 938: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 939: loss=0.000, reward_mean=0.1, reward_bound=0.0
# 940: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 941: loss=0.000, reward_mean=0.0, reward_bound=0.0
# 942: loss=0.000, reward_mean=0.1, reward_bound=0.0
# ...
# 2333: loss=0.046, reward_mean=0.0, reward_bound=0.0
# 2334: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2335: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2336: loss=0.062, reward_mean=0.1, reward_bound=0.0
# 2337: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2338: loss=0.053, reward_mean=0.1, reward_bound=0.0
# 2339: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2340: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2341: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2342: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2343: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2344: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2345: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2346: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2347: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2348: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2349: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2350: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2351: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2352: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2353: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2354: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2355: loss=0.058, reward_mean=0.0, reward_bound=0.0
# 2356: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2357: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2358: loss=0.002, reward_mean=0.2, reward_bound=0.0
# 2359: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2360: loss=0.053, reward_mean=0.0, reward_bound=0.0
# 2361: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 2362: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2363: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2364: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 2365: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2366: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2367: loss=0.001, reward_mean=0.0, reward_bound=0.0
# 2368: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2369: loss=0.065, reward_mean=0.1, reward_bound=0.0
# 2370: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2371: loss=0.053, reward_mean=0.0, reward_bound=0.0
# 2372: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2373: loss=0.002, reward_mean=0.2, reward_bound=0.0
# 2374: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2375: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 2376: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2377: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2378: loss=0.088, reward_mean=0.0, reward_bound=0.0
# 2379: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2380: loss=0.050, reward_mean=0.1, reward_bound=0.0
# 2381: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2382: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2383: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2384: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2385: loss=0.058, reward_mean=0.0, reward_bound=0.0
# 2386: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2387: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2388: loss=0.063, reward_mean=0.0, reward_bound=0.0
# 2389: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2390: loss=0.083, reward_mean=0.0, reward_bound=0.0
# 2391: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2392: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2393: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2394: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2395: loss=0.055, reward_mean=0.1, reward_bound=0.0
# 2396: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2397: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2398: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2399: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2400: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2401: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2402: loss=0.054, reward_mean=0.1, reward_bound=0.0
# 2403: loss=0.068, reward_mean=0.0, reward_bound=0.0
# 2404: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2405: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2406: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2407: loss=0.069, reward_mean=0.1, reward_bound=0.0
# 2408: loss=0.052, reward_mean=0.1, reward_bound=0.0
# 2409: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2410: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2411: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2412: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2413: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2414: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2415: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2416: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2417: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2418: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2419: loss=0.053, reward_mean=0.0, reward_bound=0.0
# 2420: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2421: loss=0.048, reward_mean=0.1, reward_bound=0.0
# 2422: loss=0.077, reward_mean=0.1, reward_bound=0.0
# 2423: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2424: loss=0.003, reward_mean=0.2, reward_bound=0.0
# 2425: loss=0.051, reward_mean=0.1, reward_bound=0.0
# 2426: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2427: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2428: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2429: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2430: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2431: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2432: loss=0.058, reward_mean=0.1, reward_bound=0.0
# 2433: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2434: loss=0.049, reward_mean=0.1, reward_bound=0.0
# 2435: loss=0.054, reward_mean=0.0, reward_bound=0.0
# 2436: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2437: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2438: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2439: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2440: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2441: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2442: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2443: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2444: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2445: loss=0.048, reward_mean=0.0, reward_bound=0.0
# 2446: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2447: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2448: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2449: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2450: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2451: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2452: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2453: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2454: loss=0.002, reward_mean=0.2, reward_bound=0.0
# 2455: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2456: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2457: loss=0.080, reward_mean=0.1, reward_bound=0.0
# 2458: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2459: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2460: loss=0.075, reward_mean=0.0, reward_bound=0.0
# 2461: loss=0.002, reward_mean=0.2, reward_bound=0.0
# 2462: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2463: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2464: loss=0.075, reward_mean=0.1, reward_bound=0.0
# 2465: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2466: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2467: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2468: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 2469: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2470: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2471: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2472: loss=0.045, reward_mean=0.1, reward_bound=0.0
# 2473: loss=0.059, reward_mean=0.0, reward_bound=0.0
# 2474: loss=0.001, reward_mean=0.1, reward_bound=0.0
# 2475: loss=0.064, reward_mean=0.0, reward_bound=0.0
# 2476: loss=0.060, reward_mean=0.0, reward_bound=0.0
# 2477: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2478: loss=0.140, reward_mean=0.0, reward_bound=0.0
# 2479: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2480: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2481: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2482: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2483: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2484: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2485: loss=0.071, reward_mean=0.0, reward_bound=0.0
# 2486: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2487: loss=0.053, reward_mean=0.0, reward_bound=0.0
# 2488: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2489: loss=0.072, reward_mean=0.0, reward_bound=0.0
# 2490: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2491: loss=0.005, reward_mean=0.1, reward_bound=0.0
# 2492: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2493: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2494: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 2495: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2496: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2497: loss=0.077, reward_mean=0.1, reward_bound=0.0
# 2498: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2499: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2500: loss=0.040, reward_mean=0.1, reward_bound=0.0
# 2501: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2502: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2503: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2504: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2505: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2506: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2507: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2508: loss=0.058, reward_mean=0.1, reward_bound=0.0
# 2509: loss=0.140, reward_mean=0.1, reward_bound=0.0
# 2510: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2511: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2512: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2513: loss=0.100, reward_mean=0.1, reward_bound=0.0
# 2514: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2515: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2516: loss=0.003, reward_mean=0.2, reward_bound=0.0
# 2517: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2518: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2519: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2520: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2521: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2522: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2523: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2524: loss=0.067, reward_mean=0.0, reward_bound=0.0
# 2525: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2526: loss=0.065, reward_mean=0.1, reward_bound=0.0
# 2527: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2528: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2529: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2530: loss=0.074, reward_mean=0.0, reward_bound=0.0
# 2531: loss=0.183, reward_mean=0.1, reward_bound=0.0
# 2532: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2533: loss=0.055, reward_mean=0.1, reward_bound=0.0
# 2534: loss=0.053, reward_mean=0.0, reward_bound=0.0
# 2535: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2536: loss=0.095, reward_mean=0.0, reward_bound=0.0
# 2537: loss=0.065, reward_mean=0.1, reward_bound=0.0
# 2538: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 2539: loss=0.076, reward_mean=0.1, reward_bound=0.0
# 2540: loss=0.007, reward_mean=0.1, reward_bound=0.0
# 2541: loss=0.008, reward_mean=0.0, reward_bound=0.0
# 2542: loss=0.007, reward_mean=0.1, reward_bound=0.0
# 2543: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 2544: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 2545: loss=0.056, reward_mean=0.0, reward_bound=0.0
# 2546: loss=0.007, reward_mean=0.1, reward_bound=0.0
# 2547: loss=0.043, reward_mean=0.0, reward_bound=0.0
# 2548: loss=0.058, reward_mean=0.0, reward_bound=0.0
# 2549: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 2550: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 2551: loss=0.049, reward_mean=0.0, reward_bound=0.0
# 2552: loss=0.009, reward_mean=0.0, reward_bound=0.0
# 2553: loss=0.054, reward_mean=0.0, reward_bound=0.0
# 2554: loss=0.009, reward_mean=0.0, reward_bound=0.0
# 2555: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 2556: loss=0.102, reward_mean=0.1, reward_bound=0.0
# 2557: loss=0.047, reward_mean=0.0, reward_bound=0.0
# 2558: loss=0.006, reward_mean=0.1, reward_bound=0.0
# 2559: loss=0.189, reward_mean=0.0, reward_bound=0.0
# 2560: loss=0.007, reward_mean=0.0, reward_bound=0.0
# 2561: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2562: loss=0.075, reward_mean=0.0, reward_bound=0.0
# 2563: loss=0.045, reward_mean=0.0, reward_bound=0.0
# 2564: loss=0.009, reward_mean=0.0, reward_bound=0.0
# 2565: loss=0.009, reward_mean=0.1, reward_bound=0.0
# 2566: loss=0.092, reward_mean=0.0, reward_bound=0.0
# 2567: loss=0.083, reward_mean=0.0, reward_bound=0.0
# 2568: loss=0.008, reward_mean=0.1, reward_bound=0.0
# 2569: loss=0.062, reward_mean=0.0, reward_bound=0.0
# 2570: loss=0.008, reward_mean=0.0, reward_bound=0.0
# 2571: loss=0.010, reward_mean=0.0, reward_bound=0.0
# 2572: loss=0.039, reward_mean=0.2, reward_bound=0.0
# 2573: loss=0.008, reward_mean=0.0, reward_bound=0.0
# 2574: loss=0.011, reward_mean=0.1, reward_bound=0.0
# 2575: loss=0.040, reward_mean=0.0, reward_bound=0.0
# 2576: loss=0.010, reward_mean=0.0, reward_bound=0.0
# 2577: loss=0.008, reward_mean=0.1, reward_bound=0.0
# 2578: loss=0.048, reward_mean=0.1, reward_bound=0.0
# 2579: loss=0.011, reward_mean=0.0, reward_bound=0.0
# 2580: loss=0.041, reward_mean=0.0, reward_bound=0.0
# 2581: loss=0.006, reward_mean=0.0, reward_bound=0.0
# 2582: loss=0.008, reward_mean=0.0, reward_bound=0.0
# 2583: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2584: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2585: loss=0.005, reward_mean=0.0, reward_bound=0.0
# 2586: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2587: loss=0.059, reward_mean=0.0, reward_bound=0.0
# 2588: loss=0.004, reward_mean=0.1, reward_bound=0.0
# 2589: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2590: loss=0.004, reward_mean=0.0, reward_bound=0.0
# 2591: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2592: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2593: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2594: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2595: loss=0.061, reward_mean=0.0, reward_bound=0.0
# 2596: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2597: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2598: loss=0.055, reward_mean=0.0, reward_bound=0.0
# 2599: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2600: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2601: loss=0.159, reward_mean=0.0, reward_bound=0.0
# 2602: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2603: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2604: loss=0.003, reward_mean=0.1, reward_bound=0.0
# 2605: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2606: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2607: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2608: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2609: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2610: loss=0.071, reward_mean=0.0, reward_bound=0.0
# 2611: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2612: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2613: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2614: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2615: loss=0.003, reward_mean=0.0, reward_bound=0.0
# 2616: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2617: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2618: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2619: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2620: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2621: loss=0.002, reward_mean=0.1, reward_bound=0.0
# 2622: loss=0.002, reward_mean=0.0, reward_bound=0.0
# 2623: loss=0.002, reward_mean=0.0, reward_bound=0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 115
#     112 optimizer = optim.Adam(params=net.parameters(), lr=0.01)
#     113 writer = SummaryWriter(comment="-frozenlake-naive")
# --> 115 for iter_no, batch in enumerate(
#     116         iterate_batches(env, net, BATCH_SIZE)):
#     117     obs_v, acts_v, reward_b, reward_m = \
#     118         filter_batch(batch, PERCENTILE)
#     119     optimizer.zero_grad()
#
# Cell In[17], line 65, in iterate_batches(env, net, batch_size)
#      63 while True:
#      64     obs_v = torch.tensor(obs, dtype=torch.float32)
# ---> 65     act_probs_v = sm(net(obs_v.unsqueeze(0)))
#      66     act_probs = act_probs_v.data.numpy()[0]
#      67     action = np.random.choice(len(act_probs), p=act_probs)
#
# KeyboardInterrupt:

# %% [markdown]
# 1. **Line 18-28**: implement `DiscreteOneHotWrapper` class/transformation as an (inherited from) `gym.ObservationWrapper`:
#     - to minimize the required changes in our implemenetation, we can apply one-hot encoding of discrete inputs (i.e. the input to our NN will have $16$ float numbers and zero everywhere, except the index that we will encode that representing our current position on the grid)
#     - with this wrapper applied to the environment, both the observation space and action space are $100%$ compatible with our CartPole solution
#         - however we can see that our training doesn't improve the score over time
#
# 2. Let's take a look of some visualizations:
#     1. Mean reward: ![FrozenLake naive mean reward](../images/ch04_frozenlake_naive_reward_mean.png)
#     2. Loss: ![FrozenLake naive loss](../images/ch04_frozenlake_naive_loss.png)
#     3. Reward boundary during the training: ![FrozenLake naive reward boundary during the training](../images/ch04_frozenlake_naive_reward_bound.png)
#
# 3. Let's take a deeper look at the reward structure of both environments:
#     1. In Cartpole, every step of the environment gives us the reward $1.0$, until the moment that the pole falls
#         - the longer our agent balanced the pole, the more reward it obtained
#         - due to randomness in agent's behavior, different episodes were of different lengths, which gave us a pretty normal distribution of the episodes' rewards
#         - after choosing a reward boundary, we rejected less successful episodes and learned how to repeat the better ones (by training on successful episodes' data)
#         - reward distribution in the CartPole environment: ![Reward distribution in the CartPole environment](../images/figure_4-9.png)
#     2. In FrozenLake, we get the reward of $1.0$ only when we reach the goal, and this reward says nothing about how good each episode was
#         - the distribution of rewards for our episodes is also problematic
#             - $2$ kinds of episodes possible, and failed episodes will obviously dominate at the beginning of the training, when the agent acts randomly
#         - so our percentile selection of elite episodes is totally wrong and gives us bad examples to train on
#         - reward distribution in the FrozenLake environment: ![Reward distribution in the FrozenLake environment](../images/figure_4-10.png)
#
# 4. This example shows us the limitations of the `CE method`:
#     1. for training, our episodes have to be finite (in general, could be infinite) and preferably short
#     2. total reward of the episodes should have enough variability to separate good episodes from bad ones
#     3. it is beneficial to have an intermediate reward during the episode instead of having the reward at the end of the episode
#
# 5. A list of tweaks:
#     1. `larger batches of played episodes`: require at leasr $100$ episodes just to get some successful episodes
#     2. `discount factor applied to the reward`: use a discoundted total reward with the discount factor of $\gamma=0.9, 0.95$ to make the total reward for an episode depend on its length, and to add variety in episodes
#         - reward for short episodes will be higher than for long ones
#         - this increases variability in reward distribution
#     3. `keeping elite episodes for a longer time`: a successful episode is rare --> keep for several iterations to train on them
#     4. `decreasing the learning rate`: give NN time to average more training samples, as a smaller lr decreases the effect of new data on the model
#     5. `much longer training time`: due to the sparsity of successful episodes and the random outcome of our actions, it's much harder for NN to get an idea of the best behavior to perform in any particular situation
#         - to reach $50%$ successful episodes, about $5000$ training iterations are required
#
# 6. Refer to [fronzenlake tweaked script](03_frozenlake_tweaked.py):

# %%
#!/usr/bin/env python3
import numpy as np
import gymnasium as gym
from dataclasses import dataclass
import typing as tt
import random
from torch.utils.tensorboard.writer import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim


HIDDEN_SIZE = 128
BATCH_SIZE = 100
PERCENTILE = 30
GAMMA = 0.9



class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env: gym.Env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space,
                          gym.spaces.Discrete)
        shape = (env.observation_space.n, )
        self.observation_space = gym.spaces.Box(
            0.0, 1.0, shape, dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res


class Net(nn.Module):
    def __init__(self, obs_size: int, hidden_size: int,
                 n_actions: int):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


@dataclass
class EpisodeStep:
    observation: np.ndarray
    action: int

@dataclass
class Episode:
    reward: float
    steps: tt.List[EpisodeStep]


def iterate_batches(env: gym.Env, net: Net, batch_size: int) -> \
        tt.Generator[tt.List[Episode], None, None]:
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs, _ = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.tensor(obs, dtype=torch.float32)
        act_probs_v = sm(net(obs_v.unsqueeze(0)))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, is_trunc, _ = env.step(action)
        episode_reward += float(reward)
        step = EpisodeStep(observation=obs, action=action)
        episode_steps.append(step)
        if is_done or is_trunc:
            e = Episode(reward=episode_reward, steps=episode_steps)
            batch.append(e)
            episode_reward = 0.0
            episode_steps = []
            next_obs, _ = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch: tt.List[Episode], percentile: float) -> \
        tt.Tuple[tt.List[Episode], tt.List[np.ndarray], tt.List[int], float]:
    reward_fun = lambda s: s.reward * (GAMMA ** len(s.steps))
    disc_rewards = list(map(reward_fun, batch))
    reward_bound = np.percentile(disc_rewards, percentile)

    train_obs: tt.List[np.ndarray] = []
    train_act: tt.List[int] = []
    elite_batch: tt.List[Episode] = []

    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation, example.steps))
            train_act.extend(map(lambda step: step.action, example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound


if __name__ == "__main__":
    random.seed(12345)
    env = DiscreteOneHotWrapper(gym.make("FrozenLake-v1"))
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.001)
    writer = SummaryWriter(comment="-frozenlake-tweaked")

    full_batch = []
    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
        reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
        full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
        if not full_batch:
            continue
        obs_v = torch.FloatTensor(np.vstack(obs))
        acts_v = torch.LongTensor(acts)
        full_batch = full_batch[-500:]

        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, rw_mean=%.3f, "
              "rw_bound=%.3f, batch=%d" % (
            iter_no, loss_v.item(), reward_mean,
            reward_bound, len(full_batch)))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_mean", reward_mean, iter_no)
        writer.add_scalar("reward_bound", reward_bound, iter_no)
        if reward_mean > 0.8:
            print("Solved!")
            break
    writer.close()
# Out:
# 1: loss=1.380, rw_mean=0.020, rw_bound=0.000, batch=2
# 2: loss=1.370, rw_mean=0.000, rw_bound=0.000, batch=2
# 3: loss=1.362, rw_mean=0.000, rw_bound=0.000, batch=2
# 4: loss=1.378, rw_mean=0.040, rw_bound=0.000, batch=6
# 5: loss=1.375, rw_mean=0.000, rw_bound=0.000, batch=6
# 6: loss=1.379, rw_mean=0.040, rw_bound=0.000, batch=10
# 7: loss=1.377, rw_mean=0.000, rw_bound=0.000, batch=10
# 8: loss=1.378, rw_mean=0.020, rw_bound=0.000, batch=12
# 9: loss=1.376, rw_mean=0.010, rw_bound=0.000, batch=13
# 10: loss=1.374, rw_mean=0.010, rw_bound=0.000, batch=14
# 11: loss=1.373, rw_mean=0.000, rw_bound=0.000, batch=14
# 12: loss=1.374, rw_mean=0.020, rw_bound=0.000, batch=16
# 13: loss=1.375, rw_mean=0.020, rw_bound=0.000, batch=18
# 14: loss=1.373, rw_mean=0.010, rw_bound=0.000, batch=19
# 15: loss=1.374, rw_mean=0.010, rw_bound=0.000, batch=20
# 16: loss=1.376, rw_mean=0.040, rw_bound=0.000, batch=24
# 17: loss=1.376, rw_mean=0.000, rw_bound=0.000, batch=24
# 18: loss=1.377, rw_mean=0.020, rw_bound=0.000, batch=26
# 19: loss=1.375, rw_mean=0.010, rw_bound=0.000, batch=27
# 20: loss=1.375, rw_mean=0.000, rw_bound=0.000, batch=27
# 21: loss=1.374, rw_mean=0.000, rw_bound=0.000, batch=27
# 22: loss=1.370, rw_mean=0.040, rw_bound=0.000, batch=31
# 23: loss=1.369, rw_mean=0.000, rw_bound=0.000, batch=31
# 24: loss=1.367, rw_mean=0.020, rw_bound=0.000, batch=33
# 25: loss=1.366, rw_mean=0.020, rw_bound=0.000, batch=35
# 26: loss=1.366, rw_mean=0.030, rw_bound=0.000, batch=38
# 27: loss=1.363, rw_mean=0.030, rw_bound=0.000, batch=41
# 28: loss=1.362, rw_mean=0.020, rw_bound=0.000, batch=43
# 29: loss=1.361, rw_mean=0.000, rw_bound=0.000, batch=43
# 30: loss=1.359, rw_mean=0.020, rw_bound=0.000, batch=45
# 31: loss=1.359, rw_mean=0.030, rw_bound=0.000, batch=48
# 32: loss=1.358, rw_mean=0.000, rw_bound=0.000, batch=48
# 33: loss=1.356, rw_mean=0.030, rw_bound=0.000, batch=51
# 34: loss=1.351, rw_mean=0.030, rw_bound=0.000, batch=54
# 35: loss=1.351, rw_mean=0.020, rw_bound=0.000, batch=56
# 36: loss=1.350, rw_mean=0.000, rw_bound=0.000, batch=56
# 37: loss=1.349, rw_mean=0.010, rw_bound=0.000, batch=57
# 38: loss=1.348, rw_mean=0.000, rw_bound=0.000, batch=57
# 39: loss=1.347, rw_mean=0.000, rw_bound=0.000, batch=57
# 40: loss=1.347, rw_mean=0.010, rw_bound=0.000, batch=58
# 41: loss=1.343, rw_mean=0.030, rw_bound=0.000, batch=61
# 42: loss=1.342, rw_mean=0.040, rw_bound=0.000, batch=65
# 43: loss=1.343, rw_mean=0.030, rw_bound=0.000, batch=68
# 44: loss=1.342, rw_mean=0.020, rw_bound=0.000, batch=70
# 45: loss=1.341, rw_mean=0.020, rw_bound=0.000, batch=72
# 46: loss=1.340, rw_mean=0.020, rw_bound=0.000, batch=74
# 47: loss=1.339, rw_mean=0.000, rw_bound=0.000, batch=74
# 48: loss=1.339, rw_mean=0.030, rw_bound=0.000, batch=77
# 49: loss=1.338, rw_mean=0.010, rw_bound=0.000, batch=78
# 50: loss=1.337, rw_mean=0.020, rw_bound=0.000, batch=80
# 51: loss=1.336, rw_mean=0.020, rw_bound=0.000, batch=82
# 52: loss=1.334, rw_mean=0.020, rw_bound=0.000, batch=84
# 53: loss=1.333, rw_mean=0.000, rw_bound=0.000, batch=84
# 54: loss=1.333, rw_mean=0.020, rw_bound=0.000, batch=86
# 55: loss=1.332, rw_mean=0.000, rw_bound=0.000, batch=86
# 56: loss=1.333, rw_mean=0.040, rw_bound=0.000, batch=90
# 57: loss=1.332, rw_mean=0.000, rw_bound=0.000, batch=90
# 58: loss=1.332, rw_mean=0.000, rw_bound=0.000, batch=90
# 59: loss=1.333, rw_mean=0.020, rw_bound=0.000, batch=92
# 60: loss=1.336, rw_mean=0.020, rw_bound=0.000, batch=94
# 61: loss=1.336, rw_mean=0.020, rw_bound=0.000, batch=96
# 62: loss=1.335, rw_mean=0.010, rw_bound=0.000, batch=97
# 63: loss=1.335, rw_mean=0.010, rw_bound=0.000, batch=98
# 64: loss=1.335, rw_mean=0.020, rw_bound=0.000, batch=100
# 65: loss=1.332, rw_mean=0.040, rw_bound=0.000, batch=104
# 66: loss=1.331, rw_mean=0.010, rw_bound=0.000, batch=105
# 67: loss=1.332, rw_mean=0.040, rw_bound=0.000, batch=109
# 68: loss=1.332, rw_mean=0.010, rw_bound=0.000, batch=110
# 69: loss=1.331, rw_mean=0.020, rw_bound=0.000, batch=112
# 70: loss=1.330, rw_mean=0.020, rw_bound=0.000, batch=114
# 71: loss=1.330, rw_mean=0.020, rw_bound=0.000, batch=116
# 72: loss=1.329, rw_mean=0.050, rw_bound=0.000, batch=121
# 73: loss=1.327, rw_mean=0.030, rw_bound=0.000, batch=124
# 74: loss=1.326, rw_mean=0.000, rw_bound=0.000, batch=124
# 75: loss=1.326, rw_mean=0.020, rw_bound=0.000, batch=126
# 76: loss=1.324, rw_mean=0.040, rw_bound=0.000, batch=130
# 77: loss=1.323, rw_mean=0.010, rw_bound=0.000, batch=131
# 78: loss=1.322, rw_mean=0.020, rw_bound=0.000, batch=133
# 79: loss=1.321, rw_mean=0.050, rw_bound=0.000, batch=138
# 80: loss=1.320, rw_mean=0.030, rw_bound=0.000, batch=141
# 81: loss=1.321, rw_mean=0.040, rw_bound=0.000, batch=145
# 82: loss=1.321, rw_mean=0.010, rw_bound=0.000, batch=146
# 83: loss=1.321, rw_mean=0.010, rw_bound=0.000, batch=147
# 84: loss=1.320, rw_mean=0.020, rw_bound=0.000, batch=149
# 85: loss=1.319, rw_mean=0.030, rw_bound=0.000, batch=152
# 86: loss=1.317, rw_mean=0.010, rw_bound=0.000, batch=153
# 87: loss=1.315, rw_mean=0.080, rw_bound=0.000, batch=161
# 88: loss=1.316, rw_mean=0.060, rw_bound=0.000, batch=167
# 89: loss=1.316, rw_mean=0.010, rw_bound=0.000, batch=168
# 90: loss=1.314, rw_mean=0.040, rw_bound=0.000, batch=172
# 91: loss=1.314, rw_mean=0.020, rw_bound=0.000, batch=174
# 92: loss=1.314, rw_mean=0.030, rw_bound=0.000, batch=177
# 93: loss=1.313, rw_mean=0.010, rw_bound=0.000, batch=178
# 94: loss=1.312, rw_mean=0.040, rw_bound=0.000, batch=182
# 95: loss=1.312, rw_mean=0.010, rw_bound=0.000, batch=183
# 96: loss=1.312, rw_mean=0.030, rw_bound=0.000, batch=186
# 97: loss=1.312, rw_mean=0.000, rw_bound=0.000, batch=186
# 98: loss=1.311, rw_mean=0.000, rw_bound=0.000, batch=186
# 99: loss=1.310, rw_mean=0.040, rw_bound=0.000, batch=190
# 100: loss=1.310, rw_mean=0.030, rw_bound=0.000, batch=193
# 101: loss=1.309, rw_mean=0.030, rw_bound=0.000, batch=196
# 102: loss=1.309, rw_mean=0.010, rw_bound=0.000, batch=197
# 103: loss=1.309, rw_mean=0.030, rw_bound=0.000, batch=200
# 104: loss=1.308, rw_mean=0.060, rw_bound=0.000, batch=206
# 105: loss=1.308, rw_mean=0.030, rw_bound=0.000, batch=209
# 106: loss=1.306, rw_mean=0.040, rw_bound=0.000, batch=213
# 107: loss=1.305, rw_mean=0.060, rw_bound=0.012, batch=219
# 108: loss=1.305, rw_mean=0.030, rw_bound=0.000, batch=222
# 109: loss=1.304, rw_mean=0.030, rw_bound=0.006, batch=225
# 110: loss=1.303, rw_mean=0.020, rw_bound=0.004, batch=227
# 111: loss=1.303, rw_mean=0.030, rw_bound=0.024, batch=229
# 112: loss=1.303, rw_mean=0.010, rw_bound=0.010, batch=230
# 113: loss=1.301, rw_mean=0.040, rw_bound=0.041, batch=231
# 114: loss=1.296, rw_mean=0.040, rw_bound=0.072, batch=230
# 115: loss=1.297, rw_mean=0.020, rw_bound=0.080, batch=228
# 116: loss=1.291, rw_mean=0.060, rw_bound=0.100, batch=229
# 117: loss=1.291, rw_mean=0.000, rw_bound=0.000, batch=229
# 118: loss=1.290, rw_mean=0.070, rw_bound=0.109, batch=226
# 119: loss=1.288, rw_mean=0.070, rw_bound=0.122, batch=227
# 120: loss=1.288, rw_mean=0.010, rw_bound=0.000, batch=228
# 121: loss=1.284, rw_mean=0.040, rw_bound=0.135, batch=228
# 122: loss=1.282, rw_mean=0.030, rw_bound=0.150, batch=225
# 123: loss=1.278, rw_mean=0.040, rw_bound=0.167, batch=220
# 124: loss=1.271, rw_mean=0.050, rw_bound=0.185, batch=215
# 125: loss=1.270, rw_mean=0.020, rw_bound=0.000, batch=217
# 126: loss=1.269, rw_mean=0.020, rw_bound=0.000, batch=219
# 127: loss=1.268, rw_mean=0.050, rw_bound=0.114, batch=223
# 128: loss=1.268, rw_mean=0.020, rw_bound=0.000, batch=225
# 129: loss=1.265, rw_mean=0.060, rw_bound=0.153, batch=227
# 130: loss=1.264, rw_mean=0.030, rw_bound=0.158, batch=229
# 131: loss=1.259, rw_mean=0.060, rw_bound=0.206, batch=214
# 132: loss=1.259, rw_mean=0.060, rw_bound=0.135, batch=220
# 133: loss=1.257, rw_mean=0.060, rw_bound=0.205, batch=224
# 134: loss=1.255, rw_mean=0.030, rw_bound=0.185, batch=227
# 135: loss=1.254, rw_mean=0.050, rw_bound=0.224, batch=229
# 136: loss=1.254, rw_mean=0.020, rw_bound=0.229, batch=218
# 137: loss=1.252, rw_mean=0.020, rw_bound=0.000, batch=220
# 138: loss=1.252, rw_mean=0.020, rw_bound=0.000, batch=222
# 139: loss=1.252, rw_mean=0.030, rw_bound=0.013, batch=225
# 140: loss=1.252, rw_mean=0.020, rw_bound=0.008, batch=227
# 141: loss=1.243, rw_mean=0.090, rw_bound=0.254, batch=210
# 142: loss=1.242, rw_mean=0.030, rw_bound=0.000, batch=213
# 143: loss=1.242, rw_mean=0.030, rw_bound=0.000, batch=216
# 144: loss=1.240, rw_mean=0.020, rw_bound=0.000, batch=218
# 145: loss=1.238, rw_mean=0.060, rw_bound=0.137, batch=222
# 146: loss=1.236, rw_mean=0.020, rw_bound=0.000, batch=224
# 147: loss=1.236, rw_mean=0.030, rw_bound=0.135, batch=227
# 148: loss=1.235, rw_mean=0.020, rw_bound=0.079, batch=229
# 149: loss=1.235, rw_mean=0.020, rw_bound=0.047, batch=230
# 150: loss=1.233, rw_mean=0.110, rw_bound=0.222, batch=231
# 151: loss=1.234, rw_mean=0.030, rw_bound=0.229, batch=227
# 152: loss=1.233, rw_mean=0.040, rw_bound=0.249, batch=229
# 153: loss=1.231, rw_mean=0.020, rw_bound=0.213, batch=230
# 154: loss=1.232, rw_mean=0.060, rw_bound=0.274, batch=231
# 155: loss=1.219, rw_mean=0.080, rw_bound=0.282, batch=206
# 156: loss=1.219, rw_mean=0.060, rw_bound=0.000, batch=212
# 157: loss=1.215, rw_mean=0.060, rw_bound=0.045, batch=218
# 158: loss=1.214, rw_mean=0.040, rw_bound=0.015, batch=222
# 159: loss=1.214, rw_mean=0.020, rw_bound=0.000, batch=224
# 160: loss=1.211, rw_mean=0.060, rw_bound=0.226, batch=227
# 161: loss=1.211, rw_mean=0.060, rw_bound=0.229, batch=226
# 162: loss=1.211, rw_mean=0.070, rw_bound=0.254, batch=227
# 163: loss=1.217, rw_mean=0.070, rw_bound=0.314, batch=192
# 164: loss=1.213, rw_mean=0.050, rw_bound=0.000, batch=197
# 165: loss=1.211, rw_mean=0.070, rw_bound=0.000, batch=204
# 166: loss=1.210, rw_mean=0.050, rw_bound=0.000, batch=209
# 167: loss=1.210, rw_mean=0.040, rw_bound=0.000, batch=213
# 168: loss=1.210, rw_mean=0.050, rw_bound=0.000, batch=218
# 169: loss=1.208, rw_mean=0.050, rw_bound=0.018, batch=222
# 170: loss=1.208, rw_mean=0.020, rw_bound=0.000, batch=224
# 171: loss=1.208, rw_mean=0.020, rw_bound=0.000, batch=226
# 172: loss=1.208, rw_mean=0.070, rw_bound=0.122, batch=227
# 173: loss=1.206, rw_mean=0.040, rw_bound=0.147, batch=229
# 174: loss=1.201, rw_mean=0.050, rw_bound=0.167, batch=228
# 175: loss=1.201, rw_mean=0.040, rw_bound=0.206, batch=227
# 176: loss=1.202, rw_mean=0.070, rw_bound=0.229, batch=227
# 177: loss=1.201, rw_mean=0.040, rw_bound=0.254, batch=224
# 178: loss=1.201, rw_mean=0.050, rw_bound=0.273, batch=227
# 179: loss=1.200, rw_mean=0.060, rw_bound=0.267, batch=229
# 180: loss=1.203, rw_mean=0.040, rw_bound=0.282, batch=222
# 181: loss=1.200, rw_mean=0.080, rw_bound=0.292, batch=225
# 182: loss=1.201, rw_mean=0.080, rw_bound=0.314, batch=222
# 183: loss=1.201, rw_mean=0.030, rw_bound=0.041, batch=225
# 184: loss=1.201, rw_mean=0.060, rw_bound=0.205, batch=227
# 185: loss=1.199, rw_mean=0.090, rw_bound=0.349, batch=181
# 186: loss=1.203, rw_mean=0.030, rw_bound=0.000, batch=184
# 187: loss=1.201, rw_mean=0.070, rw_bound=0.000, batch=191
# 188: loss=1.202, rw_mean=0.040, rw_bound=0.000, batch=195
# 189: loss=1.200, rw_mean=0.080, rw_bound=0.000, batch=203
# 190: loss=1.199, rw_mean=0.020, rw_bound=0.000, batch=205
# 191: loss=1.197, rw_mean=0.060, rw_bound=0.000, batch=211
# 192: loss=1.195, rw_mean=0.090, rw_bound=0.135, batch=217
# 193: loss=1.192, rw_mean=0.080, rw_bound=0.185, batch=217
# 194: loss=1.188, rw_mean=0.070, rw_bound=0.206, batch=216
# 195: loss=1.187, rw_mean=0.040, rw_bound=0.000, batch=220
# 196: loss=1.186, rw_mean=0.030, rw_bound=0.000, batch=223
# 197: loss=1.183, rw_mean=0.040, rw_bound=0.060, batch=226
# 198: loss=1.182, rw_mean=0.040, rw_bound=0.089, batch=228
# 199: loss=1.184, rw_mean=0.040, rw_bound=0.119, batch=229
# 200: loss=1.186, rw_mean=0.060, rw_bound=0.215, batch=230
# 201: loss=1.187, rw_mean=0.040, rw_bound=0.229, batch=226
# 202: loss=1.187, rw_mean=0.060, rw_bound=0.254, batch=226
# 203: loss=1.186, rw_mean=0.040, rw_bound=0.216, batch=228
# 204: loss=1.187, rw_mean=0.030, rw_bound=0.282, batch=223
# 205: loss=1.186, rw_mean=0.070, rw_bound=0.271, batch=226
# 206: loss=1.187, rw_mean=0.050, rw_bound=0.282, batch=227
# 207: loss=1.187, rw_mean=0.060, rw_bound=0.249, batch=229
# 208: loss=1.188, rw_mean=0.040, rw_bound=0.278, batch=230
# 209: loss=1.191, rw_mean=0.030, rw_bound=0.314, batch=222
# 210: loss=1.190, rw_mean=0.080, rw_bound=0.282, batch=224
# 211: loss=1.187, rw_mean=0.060, rw_bound=0.305, batch=227
# 212: loss=1.185, rw_mean=0.070, rw_bound=0.342, batch=229
# 213: loss=1.188, rw_mean=0.050, rw_bound=0.349, batch=218
# 214: loss=1.187, rw_mean=0.060, rw_bound=0.245, batch=222
# 215: loss=1.186, rw_mean=0.060, rw_bound=0.150, batch=224
# 216: loss=1.186, rw_mean=0.030, rw_bound=0.185, batch=227
# 217: loss=1.185, rw_mean=0.040, rw_bound=0.181, batch=229
# 218: loss=1.185, rw_mean=0.020, rw_bound=0.263, batch=230
# 219: loss=1.185, rw_mean=0.100, rw_bound=0.376, batch=231
# 220: loss=1.174, rw_mean=0.070, rw_bound=0.387, batch=170
# 221: loss=1.171, rw_mean=0.030, rw_bound=0.000, batch=173
# 222: loss=1.169, rw_mean=0.040, rw_bound=0.000, batch=177
# 223: loss=1.170, rw_mean=0.030, rw_bound=0.000, batch=180
# 224: loss=1.170, rw_mean=0.040, rw_bound=0.000, batch=184
# 225: loss=1.167, rw_mean=0.060, rw_bound=0.000, batch=190
# 226: loss=1.171, rw_mean=0.090, rw_bound=0.000, batch=199
# 227: loss=1.170, rw_mean=0.040, rw_bound=0.000, batch=203
# 228: loss=1.167, rw_mean=0.030, rw_bound=0.000, batch=206
# 229: loss=1.166, rw_mean=0.070, rw_bound=0.000, batch=213
# 230: loss=1.165, rw_mean=0.030, rw_bound=0.000, batch=216
# 231: loss=1.166, rw_mean=0.050, rw_bound=0.024, batch=221
# 232: loss=1.166, rw_mean=0.080, rw_bound=0.072, batch=223
# 233: loss=1.166, rw_mean=0.060, rw_bound=0.089, batch=224
# 234: loss=1.164, rw_mean=0.040, rw_bound=0.133, batch=227
# 235: loss=1.165, rw_mean=0.040, rw_bound=0.135, batch=228
# 236: loss=1.160, rw_mean=0.060, rw_bound=0.167, batch=225
# 237: loss=1.158, rw_mean=0.070, rw_bound=0.185, batch=223
# 238: loss=1.158, rw_mean=0.050, rw_bound=0.147, batch=226
# 239: loss=1.156, rw_mean=0.030, rw_bound=0.206, batch=222
# 240: loss=1.155, rw_mean=0.050, rw_bound=0.229, batch=223
# 241: loss=1.150, rw_mean=0.070, rw_bound=0.254, batch=222
# 242: loss=1.148, rw_mean=0.040, rw_bound=0.087, batch=225
# 243: loss=1.147, rw_mean=0.060, rw_bound=0.260, batch=227
# 244: loss=1.151, rw_mean=0.060, rw_bound=0.282, batch=222
# 245: loss=1.150, rw_mean=0.070, rw_bound=0.272, batch=225
# 246: loss=1.149, rw_mean=0.100, rw_bound=0.314, batch=218
# 247: loss=1.147, rw_mean=0.050, rw_bound=0.026, batch=222
# 248: loss=1.144, rw_mean=0.060, rw_bound=0.179, batch=225
# 249: loss=1.145, rw_mean=0.070, rw_bound=0.206, batch=226
# 250: loss=1.146, rw_mean=0.050, rw_bound=0.268, batch=228
# 251: loss=1.145, rw_mean=0.070, rw_bound=0.178, batch=229
# 252: loss=1.144, rw_mean=0.070, rw_bound=0.309, batch=230
# 253: loss=1.144, rw_mean=0.030, rw_bound=0.227, batch=231
# 254: loss=1.145, rw_mean=0.090, rw_bound=0.349, batch=221
# 255: loss=1.143, rw_mean=0.120, rw_bound=0.314, batch=224
# 256: loss=1.142, rw_mean=0.050, rw_bound=0.223, batch=227
# 257: loss=1.141, rw_mean=0.040, rw_bound=0.249, batch=229
# 258: loss=1.140, rw_mean=0.020, rw_bound=0.183, batch=230
# 259: loss=1.141, rw_mean=0.080, rw_bound=0.282, batch=230
# 260: loss=1.143, rw_mean=0.040, rw_bound=0.314, batch=230
# 261: loss=1.146, rw_mean=0.060, rw_bound=0.349, batch=228
# 262: loss=1.145, rw_mean=0.050, rw_bound=0.289, batch=229
# 263: loss=1.145, rw_mean=0.050, rw_bound=0.314, batch=229
# 264: loss=1.144, rw_mean=0.080, rw_bound=0.328, batch=230
# 265: loss=1.142, rw_mean=0.060, rw_bound=0.329, batch=231
# 266: loss=1.148, rw_mean=0.100, rw_bound=0.387, batch=218
# 267: loss=1.148, rw_mean=0.020, rw_bound=0.000, batch=220
# 268: loss=1.144, rw_mean=0.050, rw_bound=0.104, batch=224
# 269: loss=1.144, rw_mean=0.020, rw_bound=0.000, batch=226
# 270: loss=1.145, rw_mean=0.060, rw_bound=0.151, batch=228
# 271: loss=1.144, rw_mean=0.050, rw_bound=0.187, batch=229
# 272: loss=1.142, rw_mean=0.070, rw_bound=0.277, batch=230
# 273: loss=1.142, rw_mean=0.040, rw_bound=0.349, batch=230
# 274: loss=1.141, rw_mean=0.040, rw_bound=0.365, batch=231
# 275: loss=1.142, rw_mean=0.060, rw_bound=0.387, batch=230
# 276: loss=1.141, rw_mean=0.030, rw_bound=0.418, batch=231
# 277: loss=1.125, rw_mean=0.070, rw_bound=0.430, batch=128
# 278: loss=1.129, rw_mean=0.080, rw_bound=0.000, batch=136
# 279: loss=1.129, rw_mean=0.070, rw_bound=0.000, batch=143
# 280: loss=1.123, rw_mean=0.060, rw_bound=0.000, batch=149
# 281: loss=1.123, rw_mean=0.050, rw_bound=0.000, batch=154
# 282: loss=1.121, rw_mean=0.080, rw_bound=0.000, batch=162
# 283: loss=1.115, rw_mean=0.090, rw_bound=0.000, batch=171
# 284: loss=1.117, rw_mean=0.090, rw_bound=0.000, batch=180
# 285: loss=1.113, rw_mean=0.030, rw_bound=0.000, batch=183
# 286: loss=1.117, rw_mean=0.070, rw_bound=0.000, batch=190
# 287: loss=1.119, rw_mean=0.050, rw_bound=0.000, batch=195
# 288: loss=1.118, rw_mean=0.050, rw_bound=0.000, batch=200
# 289: loss=1.118, rw_mean=0.030, rw_bound=0.000, batch=203
# 290: loss=1.115, rw_mean=0.060, rw_bound=0.000, batch=209
# 291: loss=1.115, rw_mean=0.100, rw_bound=0.052, batch=216
# 292: loss=1.114, rw_mean=0.040, rw_bound=0.000, batch=220
# 293: loss=1.110, rw_mean=0.060, rw_bound=0.080, batch=223
# 294: loss=1.111, rw_mean=0.040, rw_bound=0.076, batch=226
# 295: loss=1.111, rw_mean=0.090, rw_bound=0.122, batch=227
# 296: loss=1.113, rw_mean=0.040, rw_bound=0.135, batch=223
# 297: loss=1.111, rw_mean=0.080, rw_bound=0.150, batch=225
# 298: loss=1.109, rw_mean=0.040, rw_bound=0.170, batch=227
# 299: loss=1.109, rw_mean=0.060, rw_bound=0.185, batch=227
# 300: loss=1.112, rw_mean=0.050, rw_bound=0.206, batch=226
# 301: loss=1.110, rw_mean=0.050, rw_bound=0.229, batch=222
# 302: loss=1.108, rw_mean=0.080, rw_bound=0.213, batch=225
# 303: loss=1.106, rw_mean=0.080, rw_bound=0.254, batch=221
# 304: loss=1.105, rw_mean=0.020, rw_bound=0.000, batch=223
# 305: loss=1.102, rw_mean=0.040, rw_bound=0.151, batch=226
# 306: loss=1.101, rw_mean=0.070, rw_bound=0.268, batch=228
# 307: loss=1.099, rw_mean=0.060, rw_bound=0.282, batch=213
# 308: loss=1.098, rw_mean=0.050, rw_bound=0.000, batch=218
# 309: loss=1.098, rw_mean=0.070, rw_bound=0.152, batch=222
# 310: loss=1.097, rw_mean=0.050, rw_bound=0.072, batch=225
# 311: loss=1.095, rw_mean=0.020, rw_bound=0.030, batch=227
# 312: loss=1.096, rw_mean=0.100, rw_bound=0.245, batch=229
# 313: loss=1.097, rw_mean=0.070, rw_bound=0.282, batch=229
# 314: loss=1.097, rw_mean=0.040, rw_bound=0.314, batch=212
# 315: loss=1.095, rw_mean=0.090, rw_bound=0.130, batch=218
# 316: loss=1.090, rw_mean=0.080, rw_bound=0.171, batch=222
# 317: loss=1.087, rw_mean=0.050, rw_bound=0.118, batch=225
# 318: loss=1.094, rw_mean=0.100, rw_bound=0.210, batch=227
# 319: loss=1.093, rw_mean=0.090, rw_bound=0.249, batch=229
# 320: loss=1.095, rw_mean=0.050, rw_bound=0.278, batch=230
# 321: loss=1.094, rw_mean=0.060, rw_bound=0.296, batch=231
# 322: loss=1.089, rw_mean=0.050, rw_bound=0.349, batch=213
# 323: loss=1.086, rw_mean=0.050, rw_bound=0.000, batch=218
# 324: loss=1.083, rw_mean=0.070, rw_bound=0.073, batch=222
# 325: loss=1.083, rw_mean=0.050, rw_bound=0.127, batch=225
# 326: loss=1.082, rw_mean=0.070, rw_bound=0.189, batch=227
# 327: loss=1.082, rw_mean=0.060, rw_bound=0.206, batch=227
# 328: loss=1.081, rw_mean=0.090, rw_bound=0.254, batch=228
# 329: loss=1.082, rw_mean=0.100, rw_bound=0.314, batch=227
# 330: loss=1.080, rw_mean=0.090, rw_bound=0.349, batch=226
# 331: loss=1.090, rw_mean=0.090, rw_bound=0.387, batch=198
# 332: loss=1.084, rw_mean=0.080, rw_bound=0.000, batch=206
# 333: loss=1.075, rw_mean=0.090, rw_bound=0.051, batch=214
# 334: loss=1.073, rw_mean=0.070, rw_bound=0.106, batch=220
# 335: loss=1.072, rw_mean=0.070, rw_bound=0.162, batch=224
# 336: loss=1.076, rw_mean=0.090, rw_bound=0.204, batch=227
# 337: loss=1.078, rw_mean=0.090, rw_bound=0.282, batch=223
# 338: loss=1.076, rw_mean=0.110, rw_bound=0.335, batch=226
# 339: loss=1.076, rw_mean=0.060, rw_bound=0.349, batch=224
# 340: loss=1.076, rw_mean=0.110, rw_bound=0.349, batch=225
# 341: loss=1.075, rw_mean=0.090, rw_bound=0.356, batch=227
# 342: loss=1.074, rw_mean=0.050, rw_bound=0.302, batch=229
# 343: loss=1.076, rw_mean=0.060, rw_bound=0.328, batch=230
# 344: loss=1.073, rw_mean=0.040, rw_bound=0.376, batch=231
# 345: loss=1.073, rw_mean=0.060, rw_bound=0.254, batch=231
# 346: loss=1.076, rw_mean=0.100, rw_bound=0.387, batch=224
# 347: loss=1.077, rw_mean=0.100, rw_bound=0.314, batch=226
# 348: loss=1.077, rw_mean=0.040, rw_bound=0.316, batch=228
# 349: loss=1.078, rw_mean=0.060, rw_bound=0.317, batch=229
# 350: loss=1.076, rw_mean=0.080, rw_bound=0.349, batch=227
# 351: loss=1.076, rw_mean=0.050, rw_bound=0.387, batch=228
# 352: loss=1.096, rw_mean=0.100, rw_bound=0.430, batch=197
# 353: loss=1.097, rw_mean=0.080, rw_bound=0.000, batch=205
# 354: loss=1.094, rw_mean=0.100, rw_bound=0.064, batch=213
# 355: loss=1.093, rw_mean=0.020, rw_bound=0.000, batch=215
# 356: loss=1.094, rw_mean=0.030, rw_bound=0.000, batch=218
# 357: loss=1.092, rw_mean=0.090, rw_bound=0.169, batch=222
# 358: loss=1.092, rw_mean=0.070, rw_bound=0.229, batch=223
# 359: loss=1.087, rw_mean=0.120, rw_bound=0.282, batch=225
# 360: loss=1.086, rw_mean=0.040, rw_bound=0.166, batch=227
# 361: loss=1.088, rw_mean=0.080, rw_bound=0.314, batch=215
# 362: loss=1.086, rw_mean=0.080, rw_bound=0.216, batch=220
# 363: loss=1.083, rw_mean=0.090, rw_bound=0.282, batch=222
# 364: loss=1.086, rw_mean=0.110, rw_bound=0.349, batch=218
# 365: loss=1.085, rw_mean=0.080, rw_bound=0.192, batch=222
# 366: loss=1.083, rw_mean=0.060, rw_bound=0.272, batch=225
# 367: loss=1.083, rw_mean=0.060, rw_bound=0.314, batch=224
# 368: loss=1.082, rw_mean=0.060, rw_bound=0.271, batch=227
# 369: loss=1.082, rw_mean=0.040, rw_bound=0.253, batch=229
# 370: loss=1.080, rw_mean=0.100, rw_bound=0.295, batch=230
# 371: loss=1.085, rw_mean=0.120, rw_bound=0.387, batch=219
# 372: loss=1.082, rw_mean=0.030, rw_bound=0.000, batch=222
# 373: loss=1.081, rw_mean=0.050, rw_bound=0.082, batch=225
# 374: loss=1.082, rw_mean=0.050, rw_bound=0.184, batch=227
# 375: loss=1.082, rw_mean=0.040, rw_bound=0.229, batch=228
# 376: loss=1.077, rw_mean=0.050, rw_bound=0.282, batch=228
# 377: loss=1.080, rw_mean=0.080, rw_bound=0.349, batch=228
# 378: loss=1.081, rw_mean=0.070, rw_bound=0.387, batch=226
# 379: loss=1.081, rw_mean=0.070, rw_bound=0.349, batch=227
# 380: loss=1.080, rw_mean=0.040, rw_bound=0.254, batch=228
# 381: loss=1.080, rw_mean=0.040, rw_bound=0.217, batch=229
# 382: loss=1.082, rw_mean=0.070, rw_bound=0.328, batch=230
# 383: loss=1.080, rw_mean=0.030, rw_bound=0.376, batch=231
# 384: loss=1.085, rw_mean=0.090, rw_bound=0.430, batch=217
# 385: loss=1.085, rw_mean=0.070, rw_bound=0.210, batch=222
# 386: loss=1.086, rw_mean=0.060, rw_bound=0.185, batch=225
# 387: loss=1.083, rw_mean=0.080, rw_bound=0.260, batch=227
# 388: loss=1.080, rw_mean=0.070, rw_bound=0.282, batch=226
# 389: loss=1.083, rw_mean=0.070, rw_bound=0.314, batch=227
# 390: loss=1.083, rw_mean=0.110, rw_bound=0.349, batch=225
# 391: loss=1.083, rw_mean=0.070, rw_bound=0.387, batch=223
# 392: loss=1.084, rw_mean=0.060, rw_bound=0.149, batch=226
# 393: loss=1.083, rw_mean=0.060, rw_bound=0.331, batch=228
# 394: loss=1.081, rw_mean=0.080, rw_bound=0.353, batch=229
# 395: loss=1.080, rw_mean=0.080, rw_bound=0.387, batch=227
# 396: loss=1.079, rw_mean=0.080, rw_bound=0.387, batch=228
# 397: loss=1.079, rw_mean=0.070, rw_bound=0.357, batch=229
# 398: loss=1.080, rw_mean=0.050, rw_bound=0.324, batch=230
# 399: loss=1.079, rw_mean=0.070, rw_bound=0.376, batch=231
# 400: loss=1.078, rw_mean=0.060, rw_bound=0.387, batch=230
# 401: loss=1.079, rw_mean=0.110, rw_bound=0.430, batch=228
# 402: loss=1.080, rw_mean=0.100, rw_bound=0.435, batch=229
# 403: loss=1.080, rw_mean=0.030, rw_bound=0.424, batch=230
# 404: loss=1.079, rw_mean=0.040, rw_bound=0.313, batch=231
# 405: loss=1.080, rw_mean=0.060, rw_bound=0.430, batch=231
# 406: loss=1.080, rw_mean=0.020, rw_bound=0.229, batch=231
# 407: loss=1.073, rw_mean=0.070, rw_bound=0.478, batch=94
# 408: loss=1.076, rw_mean=0.070, rw_bound=0.000, batch=101
# 409: loss=1.060, rw_mean=0.080, rw_bound=0.000, batch=109
# 410: loss=1.063, rw_mean=0.130, rw_bound=0.000, batch=122
# 411: loss=1.059, rw_mean=0.070, rw_bound=0.000, batch=129
# 412: loss=1.049, rw_mean=0.090, rw_bound=0.000, batch=138
# 413: loss=1.052, rw_mean=0.020, rw_bound=0.000, batch=140
# 414: loss=1.052, rw_mean=0.120, rw_bound=0.000, batch=152
# 415: loss=1.051, rw_mean=0.050, rw_bound=0.000, batch=157
# 416: loss=1.048, rw_mean=0.020, rw_bound=0.000, batch=159
# 417: loss=1.045, rw_mean=0.080, rw_bound=0.000, batch=167
# 418: loss=1.045, rw_mean=0.130, rw_bound=0.000, batch=180
# 419: loss=1.043, rw_mean=0.070, rw_bound=0.000, batch=187
# 420: loss=1.044, rw_mean=0.060, rw_bound=0.000, batch=193
# 421: loss=1.048, rw_mean=0.080, rw_bound=0.000, batch=201
# 422: loss=1.044, rw_mean=0.050, rw_bound=0.000, batch=206
# 423: loss=1.043, rw_mean=0.090, rw_bound=0.021, batch=214
# 424: loss=1.040, rw_mean=0.070, rw_bound=0.031, batch=220
# 425: loss=1.032, rw_mean=0.090, rw_bound=0.063, batch=224
# 426: loss=1.033, rw_mean=0.060, rw_bound=0.087, batch=227
# 427: loss=1.035, rw_mean=0.120, rw_bound=0.109, batch=228
# 428: loss=1.026, rw_mean=0.070, rw_bound=0.150, batch=226
# 429: loss=1.038, rw_mean=0.080, rw_bound=0.167, batch=223
# 430: loss=1.042, rw_mean=0.090, rw_bound=0.185, batch=218
# 431: loss=1.039, rw_mean=0.040, rw_bound=0.021, batch=222
# 432: loss=1.040, rw_mean=0.080, rw_bound=0.185, batch=224
# 433: loss=1.039, rw_mean=0.060, rw_bound=0.206, batch=214
# 434: loss=1.037, rw_mean=0.060, rw_bound=0.023, batch=220
# 435: loss=1.032, rw_mean=0.070, rw_bound=0.205, batch=224
# 436: loss=1.032, rw_mean=0.040, rw_bound=0.117, batch=227
# 437: loss=1.030, rw_mean=0.080, rw_bound=0.229, batch=214
# 438: loss=1.026, rw_mean=0.080, rw_bound=0.182, batch=220
# 439: loss=1.022, rw_mean=0.080, rw_bound=0.254, batch=210
# 440: loss=1.023, rw_mean=0.070, rw_bound=0.095, batch=217
# 441: loss=1.021, rw_mean=0.120, rw_bound=0.254, batch=220
# 442: loss=1.021, rw_mean=0.040, rw_bound=0.130, batch=224
# 443: loss=1.021, rw_mean=0.050, rw_bound=0.143, batch=227
# 444: loss=1.024, rw_mean=0.060, rw_bound=0.167, batch=228
# 445: loss=1.019, rw_mean=0.110, rw_bound=0.282, batch=208
# 446: loss=1.020, rw_mean=0.090, rw_bound=0.152, batch=215
# 447: loss=1.022, rw_mean=0.090, rw_bound=0.141, batch=220
# 448: loss=1.020, rw_mean=0.110, rw_bound=0.200, batch=224
# 449: loss=1.017, rw_mean=0.060, rw_bound=0.206, batch=226
# 450: loss=1.018, rw_mean=0.020, rw_bound=0.075, batch=228
# 451: loss=1.020, rw_mean=0.070, rw_bound=0.254, batch=223
# 452: loss=1.016, rw_mean=0.120, rw_bound=0.301, batch=226
# 453: loss=1.025, rw_mean=0.100, rw_bound=0.314, batch=210
# 454: loss=1.020, rw_mean=0.120, rw_bound=0.229, batch=216
# 455: loss=1.020, rw_mean=0.060, rw_bound=0.143, batch=221
# 456: loss=1.018, rw_mean=0.070, rw_bound=0.185, batch=224
# 457: loss=1.024, rw_mean=0.130, rw_bound=0.252, batch=227
# 458: loss=1.023, rw_mean=0.100, rw_bound=0.277, batch=229
# 459: loss=1.026, rw_mean=0.060, rw_bound=0.282, batch=226
# 460: loss=1.022, rw_mean=0.110, rw_bound=0.314, batch=222
# 461: loss=1.020, rw_mean=0.060, rw_bound=0.191, batch=225
# 462: loss=1.021, rw_mean=0.100, rw_bound=0.314, batch=225
# 463: loss=1.014, rw_mean=0.130, rw_bound=0.349, batch=201
# 464: loss=1.009, rw_mean=0.090, rw_bound=0.000, batch=210
# 465: loss=1.007, rw_mean=0.080, rw_bound=0.101, batch=217
# 466: loss=1.009, rw_mean=0.080, rw_bound=0.150, batch=221
# 467: loss=1.017, rw_mean=0.050, rw_bound=0.206, batch=222
# 468: loss=1.017, rw_mean=0.120, rw_bound=0.282, batch=222
# 469: loss=1.015, rw_mean=0.080, rw_bound=0.292, batch=225
# 470: loss=1.017, rw_mean=0.120, rw_bound=0.314, batch=219
# 471: loss=1.019, rw_mean=0.110, rw_bound=0.314, batch=221
# 472: loss=1.015, rw_mean=0.110, rw_bound=0.349, batch=220
# 473: loss=1.019, rw_mean=0.110, rw_bound=0.387, batch=191
# 474: loss=1.011, rw_mean=0.110, rw_bound=0.000, batch=202
# 475: loss=1.002, rw_mean=0.050, rw_bound=0.000, batch=207
# 476: loss=0.996, rw_mean=0.120, rw_bound=0.089, batch=213
# 477: loss=0.993, rw_mean=0.060, rw_bound=0.025, batch=219
# 478: loss=0.993, rw_mean=0.080, rw_bound=0.127, batch=223
# 479: loss=0.990, rw_mean=0.040, rw_bound=0.095, batch=226
# 480: loss=0.996, rw_mean=0.060, rw_bound=0.135, batch=227
# 481: loss=0.994, rw_mean=0.070, rw_bound=0.182, batch=229
# 482: loss=0.996, rw_mean=0.070, rw_bound=0.185, batch=229
# 483: loss=1.007, rw_mean=0.130, rw_bound=0.229, batch=228
# 484: loss=1.007, rw_mean=0.050, rw_bound=0.254, batch=227
# 485: loss=1.001, rw_mean=0.100, rw_bound=0.314, batch=227
# 486: loss=1.001, rw_mean=0.050, rw_bound=0.245, batch=229
# 487: loss=1.008, rw_mean=0.100, rw_bound=0.349, batch=222
# 488: loss=1.010, rw_mean=0.070, rw_bound=0.214, batch=225
# 489: loss=1.008, rw_mean=0.070, rw_bound=0.296, batch=227
# 490: loss=1.007, rw_mean=0.100, rw_bound=0.349, batch=228
# 491: loss=1.008, rw_mean=0.060, rw_bound=0.353, batch=229
# 492: loss=1.009, rw_mean=0.060, rw_bound=0.307, batch=230
# 493: loss=1.009, rw_mean=0.050, rw_bound=0.314, batch=230
# 494: loss=1.010, rw_mean=0.090, rw_bound=0.376, batch=231
# 495: loss=1.014, rw_mean=0.060, rw_bound=0.387, batch=214
# 496: loss=1.008, rw_mean=0.090, rw_bound=0.197, batch=220
# 497: loss=1.009, rw_mean=0.090, rw_bound=0.180, batch=224
# 498: loss=1.006, rw_mean=0.080, rw_bound=0.204, batch=227
# 499: loss=1.008, rw_mean=0.050, rw_bound=0.229, batch=228
# 500: loss=1.013, rw_mean=0.140, rw_bound=0.314, batch=227
# 501: loss=1.014, rw_mean=0.060, rw_bound=0.342, batch=229
# 502: loss=1.013, rw_mean=0.060, rw_bound=0.278, batch=230
# 503: loss=1.014, rw_mean=0.090, rw_bound=0.349, batch=226
# 504: loss=1.015, rw_mean=0.160, rw_bound=0.387, batch=223
# 505: loss=1.015, rw_mean=0.080, rw_bound=0.387, batch=225
# 506: loss=1.015, rw_mean=0.050, rw_bound=0.266, batch=227
# 507: loss=1.013, rw_mean=0.050, rw_bound=0.302, batch=229
# 508: loss=1.012, rw_mean=0.050, rw_bound=0.328, batch=230
# 509: loss=1.012, rw_mean=0.050, rw_bound=0.314, batch=230
# 510: loss=1.013, rw_mean=0.070, rw_bound=0.376, batch=231
# 511: loss=1.012, rw_mean=0.070, rw_bound=0.387, batch=229
# 512: loss=1.021, rw_mean=0.070, rw_bound=0.430, batch=175
# 513: loss=1.020, rw_mean=0.040, rw_bound=0.000, batch=179
# 514: loss=1.006, rw_mean=0.100, rw_bound=0.000, batch=189
# 515: loss=1.001, rw_mean=0.130, rw_bound=0.019, batch=202
# 516: loss=0.998, rw_mean=0.030, rw_bound=0.000, batch=205
# 517: loss=0.992, rw_mean=0.130, rw_bound=0.077, batch=213
# 518: loss=0.993, rw_mean=0.090, rw_bound=0.112, batch=219
# 519: loss=0.992, rw_mean=0.060, rw_bound=0.108, batch=223
# 520: loss=0.994, rw_mean=0.050, rw_bound=0.130, batch=226
# 521: loss=0.997, rw_mean=0.100, rw_bound=0.167, batch=226
# 522: loss=1.002, rw_mean=0.070, rw_bound=0.229, batch=224
# 523: loss=0.999, rw_mean=0.070, rw_bound=0.252, batch=227
# 524: loss=0.996, rw_mean=0.100, rw_bound=0.254, batch=226
# 525: loss=1.000, rw_mean=0.130, rw_bound=0.282, batch=220
# 526: loss=0.998, rw_mean=0.120, rw_bound=0.222, batch=224
# 527: loss=0.997, rw_mean=0.070, rw_bound=0.252, batch=227
# 528: loss=0.997, rw_mean=0.060, rw_bound=0.282, batch=227
# 529: loss=0.991, rw_mean=0.080, rw_bound=0.314, batch=216
# 530: loss=0.991, rw_mean=0.050, rw_bound=0.075, batch=221
# 531: loss=0.988, rw_mean=0.160, rw_bound=0.254, batch=224
# 532: loss=0.990, rw_mean=0.130, rw_bound=0.345, batch=227
# 533: loss=0.998, rw_mean=0.090, rw_bound=0.349, batch=220
# 534: loss=0.998, rw_mean=0.130, rw_bound=0.338, batch=224
# 535: loss=0.997, rw_mean=0.090, rw_bound=0.384, batch=227
# 536: loss=0.997, rw_mean=0.080, rw_bound=0.349, batch=228
# 537: loss=1.004, rw_mean=0.060, rw_bound=0.387, batch=214
# 538: loss=1.002, rw_mean=0.050, rw_bound=0.000, batch=219
# 539: loss=1.000, rw_mean=0.060, rw_bound=0.182, batch=223
# 540: loss=1.001, rw_mean=0.120, rw_bound=0.254, batch=225
# 541: loss=1.000, rw_mean=0.080, rw_bound=0.282, batch=226
# 542: loss=0.998, rw_mean=0.130, rw_bound=0.314, batch=227
# 543: loss=0.996, rw_mean=0.070, rw_bound=0.220, batch=229
# 544: loss=0.996, rw_mean=0.070, rw_bound=0.215, batch=230
# 545: loss=0.994, rw_mean=0.070, rw_bound=0.304, batch=231
# 546: loss=0.996, rw_mean=0.100, rw_bound=0.314, batch=231
# 547: loss=0.998, rw_mean=0.060, rw_bound=0.349, batch=227
# 548: loss=0.996, rw_mean=0.060, rw_bound=0.198, batch=229
# 549: loss=0.996, rw_mean=0.090, rw_bound=0.324, batch=230
# 550: loss=0.996, rw_mean=0.100, rw_bound=0.347, batch=231
# 551: loss=0.993, rw_mean=0.090, rw_bound=0.387, batch=230
# 552: loss=0.992, rw_mean=0.090, rw_bound=0.304, batch=231
# 553: loss=0.994, rw_mean=0.060, rw_bound=0.349, batch=231
# 554: loss=0.994, rw_mean=0.040, rw_bound=0.349, batch=231
# 555: loss=1.006, rw_mean=0.110, rw_bound=0.430, batch=207
# 556: loss=1.003, rw_mean=0.050, rw_bound=0.000, batch=212
# 557: loss=1.001, rw_mean=0.060, rw_bound=0.024, batch=218
# 558: loss=0.997, rw_mean=0.060, rw_bound=0.152, batch=222
# 559: loss=0.995, rw_mean=0.110, rw_bound=0.292, batch=225
# 560: loss=0.994, rw_mean=0.050, rw_bound=0.246, batch=227
# 561: loss=0.995, rw_mean=0.080, rw_bound=0.314, batch=228
# 562: loss=1.002, rw_mean=0.120, rw_bound=0.349, batch=223
# 563: loss=1.002, rw_mean=0.060, rw_bound=0.372, batch=226
# 564: loss=1.002, rw_mean=0.040, rw_bound=0.298, batch=228
# 565: loss=1.002, rw_mean=0.060, rw_bound=0.314, batch=228
# 566: loss=1.001, rw_mean=0.060, rw_bound=0.286, batch=229
# 567: loss=1.000, rw_mean=0.100, rw_bound=0.328, batch=230
# 568: loss=1.002, rw_mean=0.080, rw_bound=0.387, batch=224
# 569: loss=0.999, rw_mean=0.090, rw_bound=0.277, batch=227
# 570: loss=1.000, rw_mean=0.080, rw_bound=0.308, batch=229
# 571: loss=0.998, rw_mean=0.050, rw_bound=0.328, batch=230
# 572: loss=1.000, rw_mean=0.070, rw_bound=0.349, batch=226
# 573: loss=1.000, rw_mean=0.080, rw_bound=0.409, batch=228
# 574: loss=0.998, rw_mean=0.030, rw_bound=0.092, batch=229
# 575: loss=1.002, rw_mean=0.100, rw_bound=0.405, batch=230
# 576: loss=1.001, rw_mean=0.030, rw_bound=0.395, batch=231
# 577: loss=1.006, rw_mean=0.080, rw_bound=0.430, batch=219
# 578: loss=1.005, rw_mean=0.090, rw_bound=0.314, batch=222
# 579: loss=1.006, rw_mean=0.110, rw_bound=0.254, batch=225
# 580: loss=1.005, rw_mean=0.090, rw_bound=0.321, batch=227
# 581: loss=1.005, rw_mean=0.120, rw_bound=0.308, batch=229
# 582: loss=1.004, rw_mean=0.080, rw_bound=0.328, batch=230
# 583: loss=1.001, rw_mean=0.100, rw_bound=0.349, batch=228
# 584: loss=1.005, rw_mean=0.100, rw_bound=0.387, batch=225
# 585: loss=1.007, rw_mean=0.060, rw_bound=0.337, batch=227
# 586: loss=1.006, rw_mean=0.130, rw_bound=0.430, batch=226
# 587: loss=1.008, rw_mean=0.070, rw_bound=0.316, batch=228
# 588: loss=1.004, rw_mean=0.070, rw_bound=0.392, batch=229
# 589: loss=1.004, rw_mean=0.080, rw_bound=0.430, batch=228
# 590: loss=1.004, rw_mean=0.050, rw_bound=0.330, batch=229
# 591: loss=1.004, rw_mean=0.070, rw_bound=0.381, batch=230
# 592: loss=1.005, rw_mean=0.080, rw_bound=0.338, batch=231
# 593: loss=1.002, rw_mean=0.070, rw_bound=0.349, batch=231
# 594: loss=1.002, rw_mean=0.080, rw_bound=0.387, batch=231
# 595: loss=1.003, rw_mean=0.100, rw_bound=0.430, batch=231
# 596: loss=1.003, rw_mean=0.120, rw_bound=0.430, batch=231
# 597: loss=1.003, rw_mean=0.090, rw_bound=0.349, batch=231
# 598: loss=1.032, rw_mean=0.030, rw_bound=0.478, batch=153
# 599: loss=1.022, rw_mean=0.060, rw_bound=0.000, batch=159
# 600: loss=1.023, rw_mean=0.110, rw_bound=0.000, batch=170
# 601: loss=1.015, rw_mean=0.140, rw_bound=0.000, batch=184
# 602: loss=1.014, rw_mean=0.100, rw_bound=0.000, batch=194
# 603: loss=1.018, rw_mean=0.070, rw_bound=0.000, batch=201
# 604: loss=1.014, rw_mean=0.070, rw_bound=0.000, batch=208
# 605: loss=1.012, rw_mean=0.050, rw_bound=0.000, batch=213
# 606: loss=1.007, rw_mean=0.130, rw_bound=0.095, batch=219
# 607: loss=1.019, rw_mean=0.140, rw_bound=0.150, batch=220
# 608: loss=1.025, rw_mean=0.080, rw_bound=0.180, batch=224
# 609: loss=1.028, rw_mean=0.050, rw_bound=0.185, batch=223
# 610: loss=1.026, rw_mean=0.120, rw_bound=0.220, batch=226
# 611: loss=1.025, rw_mean=0.050, rw_bound=0.229, batch=220
# 612: loss=1.026, rw_mean=0.120, rw_bound=0.254, batch=214
# 613: loss=1.024, rw_mean=0.070, rw_bound=0.097, batch=220
# 614: loss=1.024, rw_mean=0.080, rw_bound=0.175, batch=224
# 615: loss=1.023, rw_mean=0.080, rw_bound=0.204, batch=227
# 616: loss=1.022, rw_mean=0.070, rw_bound=0.206, batch=227
# 617: loss=1.020, rw_mean=0.060, rw_bound=0.277, batch=229
# 618: loss=1.022, rw_mean=0.120, rw_bound=0.282, batch=221
# 619: loss=1.022, rw_mean=0.080, rw_bound=0.254, batch=224
# 620: loss=1.020, rw_mean=0.110, rw_bound=0.311, batch=227
# 621: loss=1.018, rw_mean=0.040, rw_bound=0.185, batch=228
# 622: loss=1.018, rw_mean=0.050, rw_bound=0.286, batch=229
# 623: loss=1.014, rw_mean=0.070, rw_bound=0.314, batch=217
# 624: loss=1.021, rw_mean=0.100, rw_bound=0.349, batch=207
# 625: loss=1.015, rw_mean=0.040, rw_bound=0.000, batch=211
# 626: loss=1.020, rw_mean=0.110, rw_bound=0.167, batch=216
# 627: loss=1.018, rw_mean=0.050, rw_bound=0.075, batch=221
# 628: loss=1.018, rw_mean=0.060, rw_bound=0.229, batch=223
# 629: loss=1.017, rw_mean=0.090, rw_bound=0.282, batch=225
# 630: loss=1.016, rw_mean=0.050, rw_bound=0.246, batch=227
# 631: loss=1.016, rw_mean=0.080, rw_bound=0.292, batch=229
# 632: loss=1.017, rw_mean=0.080, rw_bound=0.314, batch=226
# 633: loss=1.016, rw_mean=0.090, rw_bound=0.349, batch=225
# 634: loss=1.014, rw_mean=0.080, rw_bound=0.356, batch=227
# 635: loss=1.014, rw_mean=0.060, rw_bound=0.380, batch=229
# 636: loss=1.014, rw_mean=0.100, rw_bound=0.364, batch=230
# 637: loss=1.015, rw_mean=0.030, rw_bound=0.316, batch=231
# 638: loss=1.022, rw_mean=0.090, rw_bound=0.387, batch=204
# 639: loss=1.024, rw_mean=0.040, rw_bound=0.000, batch=208
# 640: loss=1.017, rw_mean=0.070, rw_bound=0.005, batch=215
# 641: loss=1.015, rw_mean=0.090, rw_bound=0.150, batch=219
# 642: loss=1.013, rw_mean=0.080, rw_bound=0.140, batch=223
# 643: loss=1.013, rw_mean=0.070, rw_bound=0.178, batch=226
# 644: loss=1.005, rw_mean=0.060, rw_bound=0.206, batch=227
# 645: loss=1.007, rw_mean=0.100, rw_bound=0.254, batch=228
# 646: loss=1.010, rw_mean=0.060, rw_bound=0.314, batch=224
# 647: loss=1.010, rw_mean=0.060, rw_bound=0.183, batch=227
# 648: loss=1.009, rw_mean=0.080, rw_bound=0.254, batch=228
# 649: loss=1.008, rw_mean=0.070, rw_bound=0.286, batch=229
# 650: loss=1.011, rw_mean=0.060, rw_bound=0.349, batch=225
# 651: loss=1.010, rw_mean=0.080, rw_bound=0.356, batch=227
# 652: loss=1.010, rw_mean=0.100, rw_bound=0.387, batch=225
# 653: loss=1.018, rw_mean=0.110, rw_bound=0.430, batch=189
# 654: loss=1.019, rw_mean=0.060, rw_bound=0.000, batch=195
# 655: loss=1.008, rw_mean=0.120, rw_bound=0.044, batch=206
# 656: loss=1.007, rw_mean=0.070, rw_bound=0.000, batch=213
# 657: loss=1.007, rw_mean=0.080, rw_bound=0.085, batch=219
# 658: loss=1.008, rw_mean=0.070, rw_bound=0.103, batch=223
# 659: loss=1.005, rw_mean=0.070, rw_bound=0.144, batch=226
# 660: loss=1.010, rw_mean=0.090, rw_bound=0.176, batch=228
# 661: loss=1.007, rw_mean=0.100, rw_bound=0.208, batch=229
# 662: loss=1.002, rw_mean=0.110, rw_bound=0.282, batch=229
# 663: loss=1.008, rw_mean=0.110, rw_bound=0.314, batch=222
# 664: loss=1.010, rw_mean=0.050, rw_bound=0.314, batch=223
# 665: loss=1.007, rw_mean=0.040, rw_bound=0.058, batch=226
# 666: loss=1.009, rw_mean=0.090, rw_bound=0.314, batch=227
# 667: loss=1.011, rw_mean=0.100, rw_bound=0.349, batch=221
# 668: loss=1.010, rw_mean=0.080, rw_bound=0.314, batch=224
# 669: loss=1.008, rw_mean=0.080, rw_bound=0.252, batch=227
# 670: loss=1.009, rw_mean=0.080, rw_bound=0.342, batch=229
# 671: loss=1.010, rw_mean=0.130, rw_bound=0.349, batch=228
# 672: loss=1.009, rw_mean=0.050, rw_bound=0.387, batch=219
# 673: loss=1.007, rw_mean=0.100, rw_bound=0.360, batch=223
# 674: loss=1.005, rw_mean=0.070, rw_bound=0.413, batch=226
# 675: loss=1.003, rw_mean=0.040, rw_bound=0.250, batch=228
# 676: loss=1.004, rw_mean=0.080, rw_bound=0.349, batch=227
# 677: loss=1.004, rw_mean=0.110, rw_bound=0.373, batch=229
# 678: loss=1.005, rw_mean=0.100, rw_bound=0.405, batch=230
# 679: loss=1.012, rw_mean=0.100, rw_bound=0.430, batch=212
# 680: loss=1.010, rw_mean=0.080, rw_bound=0.206, batch=218
# 681: loss=1.010, rw_mean=0.080, rw_bound=0.187, batch=222
# 682: loss=1.005, rw_mean=0.110, rw_bound=0.254, batch=224
# 683: loss=1.006, rw_mean=0.060, rw_bound=0.280, batch=227
# 684: loss=1.005, rw_mean=0.100, rw_bound=0.308, batch=229
# 685: loss=1.005, rw_mean=0.040, rw_bound=0.263, batch=230
# 686: loss=1.005, rw_mean=0.120, rw_bound=0.314, batch=227
# 687: loss=1.006, rw_mean=0.060, rw_bound=0.349, batch=227
# 688: loss=1.009, rw_mean=0.080, rw_bound=0.387, batch=228
# 689: loss=1.009, rw_mean=0.100, rw_bound=0.387, batch=228
# 690: loss=1.011, rw_mean=0.070, rw_bound=0.430, batch=221
# 691: loss=1.010, rw_mean=0.110, rw_bound=0.314, batch=224
# 692: loss=1.009, rw_mean=0.040, rw_bound=0.237, batch=227
# 693: loss=1.006, rw_mean=0.060, rw_bound=0.254, batch=228
# 694: loss=1.004, rw_mean=0.060, rw_bound=0.317, batch=229
# 695: loss=1.005, rw_mean=0.080, rw_bound=0.349, batch=228
# 696: loss=1.008, rw_mean=0.070, rw_bound=0.392, batch=229
# 697: loss=1.008, rw_mean=0.130, rw_bound=0.405, batch=230
# 698: loss=1.010, rw_mean=0.100, rw_bound=0.430, batch=225
# 699: loss=1.010, rw_mean=0.090, rw_bound=0.387, batch=226
# 700: loss=1.008, rw_mean=0.090, rw_bound=0.335, batch=228
# 701: loss=1.007, rw_mean=0.130, rw_bound=0.353, batch=229
# 702: loss=1.007, rw_mean=0.040, rw_bound=0.343, batch=230
# 703: loss=1.007, rw_mean=0.070, rw_bound=0.320, batch=231
# 704: loss=1.008, rw_mean=0.090, rw_bound=0.387, batch=229
# 705: loss=1.008, rw_mean=0.090, rw_bound=0.405, batch=230
# 706: loss=1.007, rw_mean=0.090, rw_bound=0.430, batch=230
# 707: loss=1.009, rw_mean=0.070, rw_bound=0.451, batch=231
# 708: loss=1.013, rw_mean=0.070, rw_bound=0.478, batch=184
# 709: loss=1.010, rw_mean=0.080, rw_bound=0.000, batch=192
# 710: loss=1.004, rw_mean=0.060, rw_bound=0.000, batch=198
# 711: loss=1.006, rw_mean=0.140, rw_bound=0.126, batch=208
# 712: loss=1.006, rw_mean=0.020, rw_bound=0.000, batch=210
# 713: loss=1.001, rw_mean=0.090, rw_bound=0.118, batch=217
# 714: loss=1.002, rw_mean=0.060, rw_bound=0.132, batch=222
# 715: loss=0.999, rw_mean=0.040, rw_bound=0.063, batch=225
# 716: loss=1.001, rw_mean=0.050, rw_bound=0.167, batch=226
# 717: loss=1.002, rw_mean=0.090, rw_bound=0.206, batch=225
# 718: loss=1.001, rw_mean=0.080, rw_bound=0.229, batch=225
# 719: loss=1.002, rw_mean=0.060, rw_bound=0.254, batch=220
# 720: loss=1.003, rw_mean=0.040, rw_bound=0.095, batch=224
# 721: loss=0.999, rw_mean=0.050, rw_bound=0.199, batch=227
# 722: loss=1.000, rw_mean=0.050, rw_bound=0.277, batch=229
# 723: loss=0.997, rw_mean=0.100, rw_bound=0.282, batch=221
# 724: loss=0.999, rw_mean=0.050, rw_bound=0.109, batch=224
# 725: loss=1.004, rw_mean=0.060, rw_bound=0.280, batch=227
# 726: loss=1.015, rw_mean=0.060, rw_bound=0.314, batch=219
# 727: loss=1.010, rw_mean=0.070, rw_bound=0.136, batch=223
# 728: loss=1.009, rw_mean=0.100, rw_bound=0.335, batch=226
# 729: loss=1.016, rw_mean=0.050, rw_bound=0.349, batch=221
# 730: loss=1.015, rw_mean=0.090, rw_bound=0.282, batch=224
# 731: loss=1.018, rw_mean=0.060, rw_bound=0.308, batch=227
# 732: loss=1.020, rw_mean=0.070, rw_bound=0.342, batch=229
# 733: loss=1.018, rw_mean=0.060, rw_bound=0.295, batch=230
# 734: loss=1.019, rw_mean=0.060, rw_bound=0.338, batch=231
# 735: loss=1.019, rw_mean=0.070, rw_bound=0.349, batch=230
# 736: loss=1.014, rw_mean=0.090, rw_bound=0.387, batch=213
# 737: loss=1.011, rw_mean=0.080, rw_bound=0.120, batch=219
# 738: loss=1.008, rw_mean=0.060, rw_bound=0.148, batch=223
# 739: loss=1.009, rw_mean=0.080, rw_bound=0.301, batch=226
# 740: loss=1.007, rw_mean=0.040, rw_bound=0.152, batch=228
# 741: loss=1.013, rw_mean=0.100, rw_bound=0.349, batch=228
# 742: loss=1.015, rw_mean=0.080, rw_bound=0.387, batch=224
# 743: loss=1.013, rw_mean=0.070, rw_bound=0.342, batch=227
# 744: loss=1.013, rw_mean=0.050, rw_bound=0.342, batch=229
# 745: loss=1.013, rw_mean=0.100, rw_bound=0.364, batch=230
# 746: loss=1.013, rw_mean=0.050, rw_bound=0.376, batch=231
# 747: loss=1.015, rw_mean=0.070, rw_bound=0.387, batch=228
# 748: loss=1.015, rw_mean=0.090, rw_bound=0.392, batch=229
# 749: loss=1.017, rw_mean=0.070, rw_bound=0.430, batch=208
# 750: loss=1.015, rw_mean=0.070, rw_bound=0.008, batch=215
# 751: loss=1.022, rw_mean=0.080, rw_bound=0.221, batch=220
# 752: loss=1.021, rw_mean=0.080, rw_bound=0.266, batch=224
# 753: loss=1.019, rw_mean=0.110, rw_bound=0.311, batch=227
# 754: loss=1.016, rw_mean=0.070, rw_bound=0.342, batch=229
# 755: loss=1.015, rw_mean=0.090, rw_bound=0.349, batch=226
# 756: loss=1.014, rw_mean=0.040, rw_bound=0.331, batch=228
# 757: loss=1.016, rw_mean=0.070, rw_bound=0.353, batch=229
# 758: loss=1.016, rw_mean=0.110, rw_bound=0.343, batch=230
# 759: loss=1.016, rw_mean=0.040, rw_bound=0.333, batch=231
# 760: loss=1.016, rw_mean=0.060, rw_bound=0.387, batch=224
# 761: loss=1.014, rw_mean=0.100, rw_bound=0.308, batch=227
# 762: loss=1.016, rw_mean=0.110, rw_bound=0.380, batch=229
# 763: loss=1.016, rw_mean=0.070, rw_bound=0.314, batch=229
# 764: loss=1.017, rw_mean=0.070, rw_bound=0.343, batch=230
# 765: loss=1.017, rw_mean=0.090, rw_bound=0.349, batch=230
# 766: loss=1.019, rw_mean=0.070, rw_bound=0.418, batch=231
# 767: loss=1.017, rw_mean=0.050, rw_bound=0.430, batch=220
# 768: loss=1.017, rw_mean=0.120, rw_bound=0.406, batch=224
# 769: loss=1.021, rw_mean=0.070, rw_bound=0.419, batch=227
# 770: loss=1.020, rw_mean=0.120, rw_bound=0.422, batch=229
# 771: loss=1.021, rw_mean=0.080, rw_bound=0.309, batch=230
# 772: loss=1.019, rw_mean=0.100, rw_bound=0.387, batch=230
# 773: loss=1.017, rw_mean=0.050, rw_bound=0.430, batch=227
# 774: loss=1.018, rw_mean=0.100, rw_bound=0.342, batch=229
# 775: loss=1.017, rw_mean=0.090, rw_bound=0.364, batch=230
# 776: loss=1.015, rw_mean=0.090, rw_bound=0.387, batch=229
# 777: loss=1.016, rw_mean=0.120, rw_bound=0.450, batch=230
# 778: loss=1.015, rw_mean=0.130, rw_bound=0.478, batch=207
# 779: loss=1.018, rw_mean=0.080, rw_bound=0.047, batch=215
# 780: loss=1.016, rw_mean=0.090, rw_bound=0.206, batch=219
# 781: loss=1.022, rw_mean=0.070, rw_bound=0.239, batch=223
# 782: loss=1.017, rw_mean=0.060, rw_bound=0.254, batch=222
# 783: loss=1.015, rw_mean=0.060, rw_bound=0.190, batch=225
# 784: loss=1.012, rw_mean=0.010, rw_bound=0.000, batch=226
# 785: loss=1.014, rw_mean=0.060, rw_bound=0.128, batch=228
# 786: loss=1.013, rw_mean=0.060, rw_bound=0.282, batch=225
# 787: loss=1.012, rw_mean=0.070, rw_bound=0.246, batch=227
# 788: loss=1.007, rw_mean=0.060, rw_bound=0.314, batch=227
# 789: loss=1.004, rw_mean=0.080, rw_bound=0.349, batch=228
# 790: loss=1.003, rw_mean=0.100, rw_bound=0.293, batch=229
# 791: loss=1.010, rw_mean=0.090, rw_bound=0.387, batch=220
# 792: loss=1.011, rw_mean=0.060, rw_bound=0.166, batch=224
# 793: loss=1.011, rw_mean=0.040, rw_bound=0.204, batch=227
# 794: loss=1.010, rw_mean=0.070, rw_bound=0.224, batch=229
# 795: loss=1.010, rw_mean=0.150, rw_bound=0.328, batch=230
# 796: loss=1.007, rw_mean=0.110, rw_bound=0.349, batch=230
# 797: loss=1.009, rw_mean=0.120, rw_bound=0.387, batch=228
# 798: loss=1.007, rw_mean=0.050, rw_bound=0.392, batch=229
# 799: loss=1.009, rw_mean=0.100, rw_bound=0.430, batch=224
# 800: loss=1.008, rw_mean=0.070, rw_bound=0.380, batch=227
# 801: loss=1.009, rw_mean=0.090, rw_bound=0.422, batch=229
# 802: loss=1.009, rw_mean=0.090, rw_bound=0.450, batch=230
# 803: loss=1.010, rw_mean=0.090, rw_bound=0.338, batch=231
# 804: loss=1.008, rw_mean=0.020, rw_bound=0.349, batch=230
# 805: loss=1.008, rw_mean=0.080, rw_bound=0.451, batch=231
# 806: loss=1.014, rw_mean=0.100, rw_bound=0.478, batch=215
# 807: loss=1.013, rw_mean=0.130, rw_bound=0.234, batch=220
# 808: loss=1.013, rw_mean=0.080, rw_bound=0.247, batch=224
# 809: loss=1.012, rw_mean=0.040, rw_bound=0.238, batch=227
# 810: loss=1.014, rw_mean=0.070, rw_bound=0.277, batch=229
# 811: loss=1.017, rw_mean=0.130, rw_bound=0.295, batch=230
# 812: loss=1.017, rw_mean=0.030, rw_bound=0.296, batch=231
# 813: loss=1.017, rw_mean=0.040, rw_bound=0.254, batch=231
# 814: loss=1.013, rw_mean=0.020, rw_bound=0.314, batch=229
# 815: loss=1.015, rw_mean=0.110, rw_bound=0.364, batch=230
# 816: loss=1.009, rw_mean=0.060, rw_bound=0.387, batch=230
# 817: loss=1.013, rw_mean=0.110, rw_bound=0.430, batch=226
# 818: loss=1.011, rw_mean=0.110, rw_bound=0.409, batch=228
# 819: loss=1.009, rw_mean=0.050, rw_bound=0.224, batch=229
# 820: loss=1.009, rw_mean=0.070, rw_bound=0.282, batch=229
# 821: loss=1.009, rw_mean=0.130, rw_bound=0.405, batch=230
# 822: loss=1.007, rw_mean=0.030, rw_bound=0.406, batch=231
# 823: loss=1.007, rw_mean=0.020, rw_bound=0.387, batch=231
# 824: loss=1.010, rw_mean=0.070, rw_bound=0.430, batch=229
# 825: loss=1.010, rw_mean=0.050, rw_bound=0.387, batch=229
# 826: loss=1.012, rw_mean=0.150, rw_bound=0.478, batch=219
# 827: loss=1.013, rw_mean=0.060, rw_bound=0.185, batch=222
# 828: loss=1.012, rw_mean=0.050, rw_bound=0.236, batch=225
# 829: loss=1.008, rw_mean=0.050, rw_bound=0.260, batch=227
# 830: loss=1.006, rw_mean=0.060, rw_bound=0.308, batch=229
# ...
# 9849: loss=0.181, rw_mean=0.540, rw_bound=0.080, batch=218
# 9850: loss=0.180, rw_mean=0.540, rw_bound=0.109, batch=209
# 9851: loss=0.178, rw_mean=0.490, rw_bound=0.122, batch=210
# 9852: loss=0.179, rw_mean=0.510, rw_bound=0.135, batch=215
# 9853: loss=0.180, rw_mean=0.510, rw_bound=0.150, batch=197
# 9854: loss=0.178, rw_mean=0.500, rw_bound=0.167, batch=192
# 9855: loss=0.178, rw_mean=0.370, rw_bound=0.130, batch=204
# 9856: loss=0.178, rw_mean=0.440, rw_bound=0.183, batch=213
# 9857: loss=0.180, rw_mean=0.530, rw_bound=0.185, batch=192
# 9858: loss=0.179, rw_mean=0.480, rw_bound=0.206, batch=172
# 9859: loss=0.185, rw_mean=0.490, rw_bound=0.103, batch=190
# 9860: loss=0.182, rw_mean=0.520, rw_bound=0.185, batch=202
# 9861: loss=0.181, rw_mean=0.440, rw_bound=0.206, batch=208
# 9862: loss=0.177, rw_mean=0.510, rw_bound=0.229, batch=190
# 9863: loss=0.177, rw_mean=0.460, rw_bound=0.185, batch=202
# 9864: loss=0.177, rw_mean=0.510, rw_bound=0.213, batch=211
# 9865: loss=0.175, rw_mean=0.500, rw_bound=0.254, batch=185
# 9866: loss=0.175, rw_mean=0.610, rw_bound=0.185, batch=195
# 9867: loss=0.173, rw_mean=0.440, rw_bound=0.189, batch=206
# 9868: loss=0.171, rw_mean=0.490, rw_bound=0.217, batch=214
# 9869: loss=0.173, rw_mean=0.590, rw_bound=0.252, batch=220
# 9870: loss=0.173, rw_mean=0.470, rw_bound=0.254, batch=222
# 9871: loss=0.177, rw_mean=0.450, rw_bound=0.282, batch=175
# 9872: loss=0.177, rw_mean=0.500, rw_bound=0.043, batch=192
# 9873: loss=0.171, rw_mean=0.540, rw_bound=0.122, batch=203
# 9874: loss=0.174, rw_mean=0.550, rw_bound=0.206, batch=207
# 9875: loss=0.176, rw_mean=0.480, rw_bound=0.254, batch=205
# 9876: loss=0.176, rw_mean=0.440, rw_bound=0.189, batch=213
# 9877: loss=0.176, rw_mean=0.450, rw_bound=0.206, batch=217
# 9878: loss=0.175, rw_mean=0.550, rw_bound=0.245, batch=222
# 9879: loss=0.177, rw_mean=0.510, rw_bound=0.236, batch=225
# 9880: loss=0.176, rw_mean=0.440, rw_bound=0.282, batch=221
# 9881: loss=0.177, rw_mean=0.560, rw_bound=0.254, batch=224
# 9882: loss=0.178, rw_mean=0.460, rw_bound=0.280, batch=227
# 9883: loss=0.182, rw_mean=0.480, rw_bound=0.314, batch=180
# 9884: loss=0.178, rw_mean=0.530, rw_bound=0.118, batch=196
# 9885: loss=0.175, rw_mean=0.450, rw_bound=0.115, batch=207
# 9886: loss=0.183, rw_mean=0.490, rw_bound=0.185, batch=210
# 9887: loss=0.182, rw_mean=0.520, rw_bound=0.206, batch=214
# 9888: loss=0.180, rw_mean=0.540, rw_bound=0.229, batch=218
# 9889: loss=0.182, rw_mean=0.490, rw_bound=0.254, batch=220
# 9890: loss=0.181, rw_mean=0.430, rw_bound=0.259, batch=224
# 9891: loss=0.180, rw_mean=0.510, rw_bound=0.282, batch=222
# 9892: loss=0.177, rw_mean=0.540, rw_bound=0.314, batch=218
# 9893: loss=0.179, rw_mean=0.430, rw_bound=0.234, batch=222
# 9894: loss=0.179, rw_mean=0.570, rw_bound=0.282, batch=224
# 9895: loss=0.174, rw_mean=0.500, rw_bound=0.349, batch=152
# 9896: loss=0.171, rw_mean=0.440, rw_bound=0.072, batch=174
# 9897: loss=0.166, rw_mean=0.540, rw_bound=0.098, batch=191
# 9898: loss=0.165, rw_mean=0.470, rw_bound=0.135, batch=200
# 9899: loss=0.163, rw_mean=0.570, rw_bound=0.150, batch=205
# 9900: loss=0.165, rw_mean=0.560, rw_bound=0.167, batch=210
# 9901: loss=0.162, rw_mean=0.500, rw_bound=0.185, batch=212
# 9902: loss=0.165, rw_mean=0.480, rw_bound=0.206, batch=215
# 9903: loss=0.164, rw_mean=0.510, rw_bound=0.229, batch=211
# 9904: loss=0.170, rw_mean=0.520, rw_bound=0.254, batch=208
# 9905: loss=0.173, rw_mean=0.550, rw_bound=0.282, batch=200
# 9906: loss=0.167, rw_mean=0.570, rw_bound=0.314, batch=197
# 9907: loss=0.168, rw_mean=0.550, rw_bound=0.229, batch=206
# 9908: loss=0.172, rw_mean=0.500, rw_bound=0.254, batch=212
# 9909: loss=0.170, rw_mean=0.510, rw_bound=0.254, batch=217
# 9910: loss=0.169, rw_mean=0.450, rw_bound=0.277, batch=222
# 9911: loss=0.172, rw_mean=0.540, rw_bound=0.282, batch=221
# 9912: loss=0.170, rw_mean=0.510, rw_bound=0.314, batch=218
# 9913: loss=0.173, rw_mean=0.560, rw_bound=0.349, batch=199
# 9914: loss=0.173, rw_mean=0.540, rw_bound=0.215, batch=209
# 9915: loss=0.171, rw_mean=0.480, rw_bound=0.185, batch=214
# 9916: loss=0.173, rw_mean=0.540, rw_bound=0.229, batch=218
# 9917: loss=0.173, rw_mean=0.500, rw_bound=0.254, batch=217
# 9918: loss=0.172, rw_mean=0.400, rw_bound=0.240, batch=222
# 9919: loss=0.173, rw_mean=0.520, rw_bound=0.282, batch=223
# 9920: loss=0.175, rw_mean=0.450, rw_bound=0.349, batch=219
# 9921: loss=0.175, rw_mean=0.550, rw_bound=0.265, batch=223
# 9922: loss=0.176, rw_mean=0.530, rw_bound=0.282, batch=223
# 9923: loss=0.175, rw_mean=0.500, rw_bound=0.349, batch=225
# 9924: loss=0.174, rw_mean=0.590, rw_bound=0.387, batch=156
# 9925: loss=0.173, rw_mean=0.380, rw_bound=0.030, batch=179
# 9926: loss=0.174, rw_mean=0.490, rw_bound=0.072, batch=194
# 9927: loss=0.170, rw_mean=0.400, rw_bound=0.109, batch=204
# 9928: loss=0.169, rw_mean=0.570, rw_bound=0.183, batch=213
# 9929: loss=0.169, rw_mean=0.370, rw_bound=0.185, batch=218
# 9930: loss=0.169, rw_mean=0.530, rw_bound=0.206, batch=215
# 9931: loss=0.170, rw_mean=0.520, rw_bound=0.254, batch=207
# 9932: loss=0.170, rw_mean=0.500, rw_bound=0.254, batch=213
# 9933: loss=0.169, rw_mean=0.530, rw_bound=0.282, batch=208
# 9934: loss=0.168, rw_mean=0.440, rw_bound=0.282, batch=214
# 9935: loss=0.172, rw_mean=0.520, rw_bound=0.308, batch=220
# 9936: loss=0.173, rw_mean=0.500, rw_bound=0.304, batch=224
# 9937: loss=0.169, rw_mean=0.410, rw_bound=0.314, batch=208
# 9938: loss=0.170, rw_mean=0.530, rw_bound=0.257, batch=215
# 9939: loss=0.168, rw_mean=0.480, rw_bound=0.314, batch=219
# 9940: loss=0.171, rw_mean=0.560, rw_bound=0.349, batch=203
# 9941: loss=0.173, rw_mean=0.560, rw_bound=0.271, batch=212
# 9942: loss=0.171, rw_mean=0.520, rw_bound=0.191, batch=218
# 9943: loss=0.172, rw_mean=0.450, rw_bound=0.254, batch=219
# 9944: loss=0.175, rw_mean=0.420, rw_bound=0.282, batch=220
# 9945: loss=0.172, rw_mean=0.450, rw_bound=0.314, batch=221
# 9946: loss=0.171, rw_mean=0.530, rw_bound=0.282, batch=224
# 9947: loss=0.172, rw_mean=0.430, rw_bound=0.349, batch=222
# 9948: loss=0.171, rw_mean=0.440, rw_bound=0.336, batch=225
# 9949: loss=0.171, rw_mean=0.500, rw_bound=0.234, batch=227
# 9950: loss=0.170, rw_mean=0.640, rw_bound=0.349, batch=227
# 9951: loss=0.169, rw_mean=0.440, rw_bound=0.387, batch=208
# 9952: loss=0.167, rw_mean=0.560, rw_bound=0.282, batch=214
# 9953: loss=0.166, rw_mean=0.520, rw_bound=0.249, batch=220
# 9954: loss=0.169, rw_mean=0.560, rw_bound=0.282, batch=222
# 9955: loss=0.168, rw_mean=0.490, rw_bound=0.254, batch=224
# 9956: loss=0.169, rw_mean=0.540, rw_bound=0.314, batch=224
# 9957: loss=0.171, rw_mean=0.480, rw_bound=0.349, batch=225
# 9958: loss=0.170, rw_mean=0.460, rw_bound=0.356, batch=227
# 9959: loss=0.171, rw_mean=0.490, rw_bound=0.387, batch=225
# 9960: loss=0.171, rw_mean=0.490, rw_bound=0.365, batch=227
# 9961: loss=0.163, rw_mean=0.500, rw_bound=0.430, batch=130
# 9962: loss=0.156, rw_mean=0.560, rw_bound=0.028, batch=160
# 9963: loss=0.153, rw_mean=0.490, rw_bound=0.065, batch=180
# 9964: loss=0.151, rw_mean=0.490, rw_bound=0.077, batch=196
# 9965: loss=0.151, rw_mean=0.510, rw_bound=0.098, batch=204
# 9966: loss=0.154, rw_mean=0.390, rw_bound=0.098, batch=212
# 9967: loss=0.157, rw_mean=0.520, rw_bound=0.122, batch=212
# 9968: loss=0.158, rw_mean=0.500, rw_bound=0.135, batch=216
# 9969: loss=0.157, rw_mean=0.470, rw_bound=0.158, batch=221
# 9970: loss=0.162, rw_mean=0.510, rw_bound=0.185, batch=219
# 9971: loss=0.164, rw_mean=0.460, rw_bound=0.206, batch=210
# 9972: loss=0.160, rw_mean=0.500, rw_bound=0.229, batch=209
# 9973: loss=0.157, rw_mean=0.520, rw_bound=0.254, batch=200
# 9974: loss=0.156, rw_mean=0.580, rw_bound=0.282, batch=195
# 9975: loss=0.154, rw_mean=0.460, rw_bound=0.124, batch=206
# 9976: loss=0.151, rw_mean=0.500, rw_bound=0.229, batch=213
# 9977: loss=0.155, rw_mean=0.480, rw_bound=0.254, batch=216
# 9978: loss=0.153, rw_mean=0.510, rw_bound=0.282, batch=218
# 9979: loss=0.154, rw_mean=0.460, rw_bound=0.286, batch=222
# 9980: loss=0.153, rw_mean=0.550, rw_bound=0.292, batch=225
# 9981: loss=0.154, rw_mean=0.550, rw_bound=0.314, batch=207
# 9982: loss=0.153, rw_mean=0.490, rw_bound=0.277, batch=215
# 9983: loss=0.155, rw_mean=0.480, rw_bound=0.282, batch=219
# 9984: loss=0.153, rw_mean=0.550, rw_bound=0.314, batch=222
# 9985: loss=0.152, rw_mean=0.540, rw_bound=0.282, batch=224
# 9986: loss=0.153, rw_mean=0.460, rw_bound=0.311, batch=227
# 9987: loss=0.153, rw_mean=0.580, rw_bound=0.314, batch=228
# 9988: loss=0.152, rw_mean=0.590, rw_bound=0.349, batch=205
# 9989: loss=0.152, rw_mean=0.500, rw_bound=0.314, batch=210
# 9990: loss=0.149, rw_mean=0.420, rw_bound=0.229, batch=216
# 9991: loss=0.149, rw_mean=0.510, rw_bound=0.241, batch=221
# 9992: loss=0.150, rw_mean=0.510, rw_bound=0.314, batch=221
# 9993: loss=0.151, rw_mean=0.540, rw_bound=0.254, batch=223
# 9994: loss=0.153, rw_mean=0.480, rw_bound=0.301, batch=226
# 9995: loss=0.150, rw_mean=0.490, rw_bound=0.349, batch=221
# 9996: loss=0.154, rw_mean=0.550, rw_bound=0.387, batch=191
# 9997: loss=0.155, rw_mean=0.470, rw_bound=0.185, batch=203
# 9998: loss=0.154, rw_mean=0.590, rw_bound=0.229, batch=207
# 9999: loss=0.153, rw_mean=0.460, rw_bound=0.229, batch=213
# 10000: loss=0.152, rw_mean=0.560, rw_bound=0.198, batch=219
# 10001: loss=0.150, rw_mean=0.470, rw_bound=0.265, batch=223
# 10002: loss=0.151, rw_mean=0.570, rw_bound=0.301, batch=226
# 10003: loss=0.153, rw_mean=0.510, rw_bound=0.314, batch=224
# 10004: loss=0.153, rw_mean=0.520, rw_bound=0.349, batch=218
# 10005: loss=0.153, rw_mean=0.460, rw_bound=0.286, batch=222
# 10006: loss=0.152, rw_mean=0.520, rw_bound=0.349, batch=223
# 10007: loss=0.152, rw_mean=0.480, rw_bound=0.301, batch=226
# 10008: loss=0.156, rw_mean=0.500, rw_bound=0.349, batch=226
# 10009: loss=0.160, rw_mean=0.550, rw_bound=0.387, batch=215
# 10010: loss=0.162, rw_mean=0.520, rw_bound=0.312, batch=220
# 10011: loss=0.160, rw_mean=0.530, rw_bound=0.274, batch=224
# 10012: loss=0.162, rw_mean=0.490, rw_bound=0.349, batch=224
# 10013: loss=0.161, rw_mean=0.480, rw_bound=0.282, batch=226
# 10014: loss=0.161, rw_mean=0.430, rw_bound=0.409, batch=228
# 10015: loss=0.161, rw_mean=0.420, rw_bound=0.357, batch=229
# 10016: loss=0.164, rw_mean=0.560, rw_bound=0.430, batch=192
# 10017: loss=0.162, rw_mean=0.470, rw_bound=0.213, batch=204
# 10018: loss=0.164, rw_mean=0.490, rw_bound=0.226, batch=213
# 10019: loss=0.163, rw_mean=0.580, rw_bound=0.220, batch=219
# 10020: loss=0.165, rw_mean=0.410, rw_bound=0.229, batch=221
# 10021: loss=0.164, rw_mean=0.560, rw_bound=0.254, batch=224
# 10022: loss=0.163, rw_mean=0.560, rw_bound=0.282, batch=222
# 10023: loss=0.162, rw_mean=0.490, rw_bound=0.314, batch=219
# 10024: loss=0.161, rw_mean=0.460, rw_bound=0.328, batch=223
# 10025: loss=0.164, rw_mean=0.500, rw_bound=0.349, batch=215
# 10026: loss=0.166, rw_mean=0.520, rw_bound=0.240, batch=220
# 10027: loss=0.163, rw_mean=0.450, rw_bound=0.349, batch=222
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 120
#     117 writer = SummaryWriter(comment="-frozenlake-tweaked")
#     119 full_batch = []
# --> 120 for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
#     121     reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
#     122     full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
#
# Cell In[18], line 82, in iterate_batches(env, net, batch_size)
#      80 episode_reward = 0.0
#      81 episode_steps = []
# ---> 82 next_obs, _ = env.reset()
#      83 if len(batch) == batch_size:
#      84     yield batch
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\core.py:553, in ObservationWrapper.reset(self, seed, options)
#     549 def reset(
#     550     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     551 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     552     """Modifies the :attr:`env` after calling :meth:`reset`, returning a modified observation using :meth:`self.observation`."""
# --> 553     obs, info = self.env.reset(seed=seed, options=options)
#     554     return self.observation(obs), info
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\wrappers\common.py:146, in TimeLimit.reset(self, seed, options)
#     136 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#     137
#     138 Args:
#    (...)    143     The reset environment
#     144 """
#     145 self._elapsed_steps = 0
# --> 146 return super().reset(seed=seed, options=options)
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\wrappers\common.py:400, in OrderEnforcing.reset(self, seed, options)
#     398 """Resets the environment with `kwargs`."""
#     399 self._has_reset = True
# --> 400 return super().reset(seed=seed, options=options)
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\wrappers\common.py:295, in PassiveEnvChecker.reset(self, seed, options)
#     293     return env_reset_passive_checker(self.env, seed=seed, options=options)
#     294 else:
# --> 295     return self.env.reset(seed=seed, options=options)
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\envs\toy_text\frozen_lake.py:343, in FrozenLakeEnv.reset(self, seed, options)
#     336 def reset(
#     337     self,
#     338     *,
#     339     seed: int | None = None,
#     340     options: dict | None = None,
#     341 ):
#     342     super().reset(seed=seed)
# --> 343     self.s = categorical_sample(self.initial_state_distrib, self.np_random)
#     344     self.lastaction = None
#     346     if self.render_mode == "human":
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\gymnasium\envs\toy_text\utils.py:8, in categorical_sample(prob_n, np_random)
#       6 prob_n = np.asarray(prob_n)
#       7 csprob_n = np.cumsum(prob_n)
# ----> 8 return np.argmax(csprob_n > np_random.random())
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:1341, in argmax(a, axis, out, keepdims)
#    1252 """
#    1253 Returns the indices of the maximum values along an axis.
#    1254
#    (...)   1338 (2, 1, 4)
#    1339 """
#    1340 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1341 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\user\Desktop\Deep-Reinforcement-Learning-Hands-On-Third-Edition\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# 1. **Line 89-105**: change `filter_batch()` function to calculate the discounted reward and return elite episodes for us to keep
#
# 2. **Line 119-127**: in the training loop, store previous elite episodes to pass them to `filter_batch()` function on the next training iteration
#
# 3. the rest of the code is the same, except:
#     1. `lr` decreases $10\times$
#     2. `BATCHSIZE=100`
#
# 4. Let's take a look of some visualizations:
#     1. Mean reward: ![FrozenLake tweaked mean reward](../images/ch04_frozenlake_tweaked_reward_mean.png)
#     2. Loss: ![FrozenLake tweaked loss](../images/ch04_frozenlake_tweaked_loss.png)
#     3. Reward boundary during the training: ![FrozenLake tweaked reward boundary during the training](../images/ch04_frozenlake_tweaked_reward_bound.png)
#
# 5. there are ways to address this (e.g. `entropy loss regularization`) (discuss later)
#
# 6. For nonslippery version, refer to [frozenlake nonslippery script](04_frozenlake_nonslippery.py):
#     - **Line 112**: `is_slippery=False`

# %%
#!/usr/bin/env python3
import numpy as np
import gymnasium as gym
from dataclasses import dataclass
import typing as tt
import random
from torch.utils.tensorboard.writer import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim


HIDDEN_SIZE = 128
BATCH_SIZE = 100
PERCENTILE = 30
GAMMA = 0.9


class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env: gym.Env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space,
                          gym.spaces.Discrete)
        shape = (env.observation_space.n, )
        self.observation_space = gym.spaces.Box(
            0.0, 1.0, shape, dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res


class Net(nn.Module):
    def __init__(self, obs_size: int, hidden_size: int,
                 n_actions: int):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


@dataclass
class EpisodeStep:
    observation: np.ndarray
    action: int

@dataclass
class Episode:
    reward: float
    steps: tt.List[EpisodeStep]


def iterate_batches(env: gym.Env, net: Net, batch_size: int) -> \
        tt.Generator[tt.List[Episode], None, None]:
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs, _ = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.tensor(obs, dtype=torch.float32)
        act_probs_v = sm(net(obs_v.unsqueeze(0)))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, is_trunc, _ = env.step(action)
        episode_reward += float(reward)
        step = EpisodeStep(observation=obs, action=action)
        episode_steps.append(step)
        if is_done or is_trunc:
            e = Episode(reward=episode_reward, steps=episode_steps)
            batch.append(e)
            episode_reward = 0.0
            episode_steps = []
            next_obs, _ = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch: tt.List[Episode], percentile: float) -> \
        tt.Tuple[tt.List[Episode], tt.List[np.ndarray],
                 tt.List[int], float]:
    reward_fun = lambda s: s.reward * (GAMMA ** len(s.steps))
    disc_rewards = list(map(reward_fun, batch))
    reward_bound = np.percentile(disc_rewards, percentile)

    train_obs: tt.List[np.ndarray] = []
    train_act: tt.List[int] = []
    elite_batch: tt.List[Episode] = []

    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation,
                                 example.steps))
            train_act.extend(map(lambda step: step.action,
                                 example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound


if __name__ == "__main__":
    random.seed(12345)
    env = DiscreteOneHotWrapper(gym.make("FrozenLake-v1", is_slippery=False))
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.001)
    writer = SummaryWriter(comment="-frozenlake-nonslippery")

    full_batch = []
    for iter_no, batch in enumerate(iterate_batches(
            env, net, BATCH_SIZE)):
        reward_mean = float(np.mean(list(map(
            lambda s: s.reward, batch))))
        full_batch, obs, acts, reward_bound = \
            filter_batch(full_batch + batch, PERCENTILE)
        if not full_batch:
            continue
        obs_v = torch.FloatTensor(np.vstack(obs))
        acts_v = torch.LongTensor(acts)
        full_batch = full_batch[-500:]

        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, rw_mean=%.3f, "
              "rw_bound=%.3f, batch=%d" % (
            iter_no, loss_v.item(), reward_mean,
            reward_bound, len(full_batch)))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_mean", reward_mean, iter_no)
        writer.add_scalar("reward_bound", reward_bound, iter_no)
        if reward_mean > 0.8:
            print("Solved!")
            break
    writer.close()
# Out:
# 0: loss=1.410, rw_mean=0.020, rw_bound=0.000, batch=2
# 1: loss=1.403, rw_mean=0.000, rw_bound=0.000, batch=2
# 2: loss=1.397, rw_mean=0.000, rw_bound=0.000, batch=2
# 3: loss=1.388, rw_mean=0.030, rw_bound=0.000, batch=5
# 4: loss=1.382, rw_mean=0.000, rw_bound=0.000, batch=5
# 5: loss=1.378, rw_mean=0.020, rw_bound=0.000, batch=7
# 6: loss=1.373, rw_mean=0.000, rw_bound=0.000, batch=7
# 7: loss=1.362, rw_mean=0.020, rw_bound=0.000, batch=9
# 8: loss=1.353, rw_mean=0.040, rw_bound=0.000, batch=13
# 9: loss=1.348, rw_mean=0.010, rw_bound=0.000, batch=14
# 10: loss=1.342, rw_mean=0.000, rw_bound=0.000, batch=14
# 11: loss=1.335, rw_mean=0.040, rw_bound=0.000, batch=18
# 12: loss=1.330, rw_mean=0.000, rw_bound=0.000, batch=18
# 13: loss=1.335, rw_mean=0.040, rw_bound=0.000, batch=22
# 14: loss=1.335, rw_mean=0.040, rw_bound=0.000, batch=26
# 15: loss=1.333, rw_mean=0.040, rw_bound=0.000, batch=30
# 16: loss=1.329, rw_mean=0.030, rw_bound=0.000, batch=33
# 17: loss=1.327, rw_mean=0.040, rw_bound=0.000, batch=37
# 18: loss=1.323, rw_mean=0.040, rw_bound=0.000, batch=41
# 19: loss=1.319, rw_mean=0.040, rw_bound=0.000, batch=45
# 20: loss=1.316, rw_mean=0.040, rw_bound=0.000, batch=49
# 21: loss=1.312, rw_mean=0.030, rw_bound=0.000, batch=52
# 22: loss=1.307, rw_mean=0.090, rw_bound=0.000, batch=61
# 23: loss=1.301, rw_mean=0.040, rw_bound=0.000, batch=65
# 24: loss=1.299, rw_mean=0.010, rw_bound=0.000, batch=66
# 25: loss=1.295, rw_mean=0.040, rw_bound=0.000, batch=70
# 26: loss=1.291, rw_mean=0.020, rw_bound=0.000, batch=72
# 27: loss=1.288, rw_mean=0.040, rw_bound=0.000, batch=76
# 28: loss=1.283, rw_mean=0.020, rw_bound=0.000, batch=78
# 29: loss=1.278, rw_mean=0.060, rw_bound=0.000, batch=84
# 30: loss=1.276, rw_mean=0.040, rw_bound=0.000, batch=88
# 31: loss=1.275, rw_mean=0.050, rw_bound=0.000, batch=93
# 32: loss=1.269, rw_mean=0.050, rw_bound=0.000, batch=98
# 33: loss=1.266, rw_mean=0.070, rw_bound=0.000, batch=105
# 34: loss=1.262, rw_mean=0.060, rw_bound=0.000, batch=111
# 35: loss=1.259, rw_mean=0.080, rw_bound=0.000, batch=119
# 36: loss=1.256, rw_mean=0.070, rw_bound=0.000, batch=126
# 37: loss=1.251, rw_mean=0.070, rw_bound=0.000, batch=133
# 38: loss=1.248, rw_mean=0.050, rw_bound=0.000, batch=138
# 39: loss=1.244, rw_mean=0.070, rw_bound=0.000, batch=145
# 40: loss=1.238, rw_mean=0.080, rw_bound=0.000, batch=153
# 41: loss=1.232, rw_mean=0.100, rw_bound=0.000, batch=163
# 42: loss=1.229, rw_mean=0.060, rw_bound=0.000, batch=169
# 43: loss=1.224, rw_mean=0.060, rw_bound=0.000, batch=175
# 44: loss=1.221, rw_mean=0.080, rw_bound=0.000, batch=183
# 45: loss=1.216, rw_mean=0.130, rw_bound=0.000, batch=196
# 46: loss=1.213, rw_mean=0.060, rw_bound=0.000, batch=202
# 47: loss=1.203, rw_mean=0.140, rw_bound=0.067, batch=211
# 48: loss=1.191, rw_mean=0.100, rw_bound=0.080, batch=217
# 49: loss=1.181, rw_mean=0.110, rw_bound=0.107, batch=222
# 50: loss=1.163, rw_mean=0.130, rw_bound=0.135, batch=223
# 51: loss=1.147, rw_mean=0.160, rw_bound=0.167, batch=220
# 52: loss=1.137, rw_mean=0.100, rw_bound=0.185, batch=219
# 53: loss=1.123, rw_mean=0.160, rw_bound=0.206, batch=221
# 54: loss=1.103, rw_mean=0.190, rw_bound=0.229, batch=220
# 55: loss=1.081, rw_mean=0.090, rw_bound=0.254, batch=202
# 56: loss=1.055, rw_mean=0.170, rw_bound=0.282, batch=185
# 57: loss=1.055, rw_mean=0.110, rw_bound=0.000, batch=196
# 58: loss=1.047, rw_mean=0.150, rw_bound=0.241, batch=207
# 59: loss=1.042, rw_mean=0.190, rw_bound=0.282, batch=214
# 60: loss=1.007, rw_mean=0.180, rw_bound=0.314, batch=191
# 61: loss=0.999, rw_mean=0.160, rw_bound=0.314, batch=203
# 62: loss=0.954, rw_mean=0.260, rw_bound=0.349, batch=176
# 63: loss=0.947, rw_mean=0.240, rw_bound=0.298, batch=193
# 64: loss=0.942, rw_mean=0.210, rw_bound=0.314, batch=204
# 65: loss=0.927, rw_mean=0.150, rw_bound=0.349, batch=204
# 66: loss=0.871, rw_mean=0.190, rw_bound=0.387, batch=154
# 67: loss=0.876, rw_mean=0.290, rw_bound=0.254, batch=177
# 68: loss=0.862, rw_mean=0.300, rw_bound=0.314, batch=188
# 69: loss=0.848, rw_mean=0.280, rw_bound=0.349, batch=195
# 70: loss=0.770, rw_mean=0.340, rw_bound=0.430, batch=144
# 71: loss=0.814, rw_mean=0.260, rw_bound=0.000, batch=170
# 72: loss=0.781, rw_mean=0.300, rw_bound=0.314, batch=183
# 73: loss=0.748, rw_mean=0.340, rw_bound=0.387, batch=180
# 74: loss=0.722, rw_mean=0.340, rw_bound=0.430, batch=187
# 75: loss=0.716, rw_mean=0.300, rw_bound=0.422, batch=201
# 76: loss=0.698, rw_mean=0.340, rw_bound=0.430, batch=207
# 77: loss=0.608, rw_mean=0.390, rw_bound=0.478, batch=127
# 78: loss=0.691, rw_mean=0.330, rw_bound=0.170, batch=159
# 79: loss=0.645, rw_mean=0.400, rw_bound=0.349, batch=178
# 80: loss=0.617, rw_mean=0.350, rw_bound=0.387, batch=189
# 81: loss=0.577, rw_mean=0.290, rw_bound=0.430, batch=185
# 82: loss=0.543, rw_mean=0.440, rw_bound=0.478, batch=173
# 83: loss=0.530, rw_mean=0.470, rw_bound=0.478, batch=189
# 84: loss=0.518, rw_mean=0.360, rw_bound=0.478, batch=201
# 86: loss=0.803, rw_mean=0.480, rw_bound=0.000, batch=48
# 87: loss=0.797, rw_mean=0.560, rw_bound=0.208, batch=103
# 88: loss=0.771, rw_mean=0.390, rw_bound=0.137, batch=142
# 89: loss=0.685, rw_mean=0.480, rw_bound=0.349, batch=162
# 90: loss=0.631, rw_mean=0.450, rw_bound=0.387, batch=176
# 91: loss=0.548, rw_mean=0.440, rw_bound=0.430, batch=162
# 92: loss=0.448, rw_mean=0.510, rw_bound=0.478, batch=126
# 93: loss=0.457, rw_mean=0.500, rw_bound=0.430, batch=157
# 94: loss=0.434, rw_mean=0.650, rw_bound=0.478, batch=174
# 96: loss=0.668, rw_mean=0.570, rw_bound=0.000, batch=57
# 97: loss=0.647, rw_mean=0.580, rw_bound=0.314, batch=109
# 98: loss=0.575, rw_mean=0.580, rw_bound=0.387, batch=142
# 99: loss=0.487, rw_mean=0.540, rw_bound=0.430, batch=151
# 100: loss=0.399, rw_mean=0.540, rw_bound=0.478, batch=128
# 101: loss=0.391, rw_mean=0.620, rw_bound=0.484, batch=159
# 103: loss=0.555, rw_mean=0.600, rw_bound=0.000, batch=60
# 104: loss=0.511, rw_mean=0.590, rw_bound=0.387, batch=109
# 105: loss=0.453, rw_mean=0.670, rw_bound=0.430, batch=141
# 106: loss=0.369, rw_mean=0.540, rw_bound=0.478, batch=133
# 107: loss=0.364, rw_mean=0.590, rw_bound=0.478, batch=161
# 109: loss=0.615, rw_mean=0.610, rw_bound=0.000, batch=61
# 110: loss=0.516, rw_mean=0.670, rw_bound=0.387, batch=110
# 111: loss=0.422, rw_mean=0.610, rw_bound=0.430, batch=134
# 112: loss=0.339, rw_mean=0.710, rw_bound=0.478, batch=142
# 114: loss=0.574, rw_mean=0.620, rw_bound=0.000, batch=62
# 115: loss=0.403, rw_mean=0.650, rw_bound=0.430, batch=91
# 116: loss=0.323, rw_mean=0.680, rw_bound=0.478, batch=110
# 118: loss=0.522, rw_mean=0.590, rw_bound=0.000, batch=59
# 119: loss=0.394, rw_mean=0.660, rw_bound=0.430, batch=100
# 120: loss=0.320, rw_mean=0.760, rw_bound=0.478, batch=126
# 122: loss=0.368, rw_mean=0.780, rw_bound=0.430, batch=67
# 123: loss=0.302, rw_mean=0.760, rw_bound=0.478, batch=104
# 125: loss=0.467, rw_mean=0.670, rw_bound=0.000, batch=67
# 126: loss=0.296, rw_mean=0.760, rw_bound=0.478, batch=96
# 128: loss=0.426, rw_mean=0.640, rw_bound=0.000, batch=64
# 129: loss=0.287, rw_mean=0.700, rw_bound=0.478, batch=97
# 131: loss=0.373, rw_mean=0.760, rw_bound=0.387, batch=69
# 132: loss=0.284, rw_mean=0.790, rw_bound=0.478, batch=98
# 134: loss=0.277, rw_mean=0.800, rw_bound=0.478, batch=56
# 135: loss=0.278, rw_mean=0.780, rw_bound=0.478, batch=107
# 137: loss=0.344, rw_mean=0.810, rw_bound=0.430, batch=68
# Solved!

# %% [markdown]
# 1. Let's take a look of some visualizations:
#     1. Mean reward: ![FrozenLake nonslippery mean reward](../images/ch04_frozenlake_nonslippery_reward_mean.png)
#     2. Loss: ![FrozenLake nonslippery loss](../images/ch04_frozenlake_nonslippery_loss.png)
#     3. Reward boundary during the training: ![FrozenLake nonslippery reward boundary during the training](../images/ch04_frozenlake_nonslippery_reward_bound.png)

# %% [markdown]
# ## 5. The theoretical background of the cross-entropy method

# %% [markdown]
# - Refer to:
#     1. book written by Reuven Rubinstein and Dirk P. Kroese `[RK04]`
#     2. original paper by `Kroese`, title `Cross-entropy method, [Kro+11]`
#
# 1. The sampling theorem states:$$\begin{align*}
# \mathbb{E}_{x\sim p(x)}[H(x)] &= \int_{x} p(x)H(x)dx = \int_{x} q(x)\frac{p(x)}{q(x)}H(x)dx \\
# &= \mathbb{E}_{x\sim q(x)}\left[q(x)\frac{p(x)}{q(x)}H(x)\right]
# \end{align*}$$
#     - where (in RL case):
#         - $H(x)$: a reward value obtained by some policy $x$
#         - $p(x)$: a distribution of all possible policies
#     - we don't want to maximize our reward by searching all possible policies; instead, we want to find a way to approximate $p(x)H(x)$ by $q(x)$, iterative minimizing the distance between them
#
# 2. The distance between $2$ probability distributions is calculated by `Kullback-Leibler (KL) divergence`:$$\begin{align*}
# KL(p_1(x)\parallel p_2(x)) &= \mathbb{E}_{x\sim p_1(x)}\left[\log\frac{p_1(x)}{p_2(x)}\right] \\
# &= \mathbb{E}_{x\sim p_1(x)}\left[\log p_1(x)\right] - \mathbb{E}_{x\sim p_1(x)}\left[\log p_2(x)\right]
# \end{align*}$$
#     - where:
#         - $\mathbb{E}_{x\sim p_1(x)}\left[\log p_1(x)\right]$: called `entropy`, and it doesn't depend on $p_2(x)$, so it could be omitted during the minimization
#         - $\mathbb{E}_{x\sim p_1(x)}\left[\log p_2(x)\right]$: called `cross-entropy`
#
# 3. Combining both formulas, we can get an iterative algorithm. This is an approximation of $p(x)H(x)$ with an update:$$\begin{align*}
# q_0(x) &= p(x) \\
# q_{i+1}(x) &= \argmin_{q_{i+1}(x)} \left( -\mathbb{E}_{x\sim q_{i}(x)}\left[\frac{p(x)}{q_{i}(x)}H(x)\log q_{i+1}(x)\right] \right)
# \end{align*}$$
#     - this is a generic cross-entropy method that can be significant simplified in our RL case
#
# 4. Replace $H(x)$ with an indicator function ($1$ when the reward for the episode is above the threshold, and $0$ when the reward is below). Our policy update:$$\begin{align*}
# \pi_{i+1}(a|s) &= \argmin_{\pi_{i+1}} \left( -\mathbb{E}_{z\sim \pi_{i}(a|s)}\left[\left[R(z)\geq \psi_{i}\right]\log\pi_{i+1}(a|s)\right] \right)
# \end{align*}$$
#     - strictly speaking, the formula misses the normalization term, but it still works in practice without it
#     - the method is quite clear:
#         1. we sample episodes using our current policy (starting with some random inital policy), and
#         2. minimize the negative log likelihood of the most successful samples and our policy
